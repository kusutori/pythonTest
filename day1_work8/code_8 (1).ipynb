# %%
import requests as re

# %%
#把Headers中的Requests URL赋值给url
url = "https://club.jd.com/comment/productPageComments.action?callback=fetchJSON_comment98&productId=7784051&score=0&sortType=5&page=0&pageSize=10&isShadowSku=0&fold=1"

# %%
#把Headers中对应关键词后面的内容填入headers中
headers = {'User-Agent':'User-Agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/107.0.0.0 Safari/537.36 Edg/107.0.1418.62',
           'Request Method':'Get',
           'callback':'fetchJSON_comment98'}

# %%
#获取url中的所有信息
req = re.get(url, timeout=40, headers=headers)

# %%
req.text
# Out:
# ''

# %%
import json  #导入json模块


#先把不用的内容去掉，再用json库解析它，得到我们想要的内容
jd=json.loads(req.text.lstrip("fetchJSON_comme rstrip nt98vv375(").rstrip(");"))
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# d:\vscode\python\homework8\code_8 (1).ipynb Cell 6 in <cell line: 5>()
#       <a href='vscode-notebook-cell:/d%3A/vscode/python/homework8/code_8%20%281%29.ipynb#W4sZmlsZQ%3D%3D?line=0'>1</a> import json  #导入json模块
#       <a href='vscode-notebook-cell:/d%3A/vscode/python/homework8/code_8%20%281%29.ipynb#W4sZmlsZQ%3D%3D?line=3'>4</a> #先把不用的内容去掉，再用json库解析它，得到我们想要的内容
# ----> <a href='vscode-notebook-cell:/d%3A/vscode/python/homework8/code_8%20%281%29.ipynb#W4sZmlsZQ%3D%3D?line=4'>5</a> jd=json.loads(req.text.lstrip("fetchJSON_comme rstrip nt98vv375(").rstrip(");"))
#
# File c:\Users\31815\anaconda3\lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#     348     cls = JSONDecoder
#
# File c:\Users\31815\anaconda3\lib\json\decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     332 def decode(self, s, _w=WHITESPACE.match):
#     333     """Return the Python representation of ``s`` (a ``str`` instance
#     334     containing a JSON document).
#     335
#     336     """
# --> 337     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338     end = _w(s, end).end()
#     339     if end != len(s):
#
# File c:\Users\31815\anaconda3\lib\json\decoder.py:355, in JSONDecoder.raw_decode(self, s, idx)
#     353     obj, end = self.scan_once(s, idx)
#     354 except StopIteration as err:
# --> 355     raise JSONDecodeError("Expecting value", s, err.value) from None
#     356 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
jd
# Out:
# {'jwotestProduct': None,
#  'score': 0,
#  'comments': [{'id': 16171265032,
#    'guid': '79719d871a9115ae30587aacfc4ee6ae',
#    'content': '无线鼠标真心好，没有了线的烦恼，移动不受限制。\n罗技品牌很实在，性价比很高，鼠标轻巧，定位准确，手感舒适。\n连接很稳定，没有什么延迟的感觉，。\n我用来竞技游戏比502强，没有编程不影响。',
#    'creationTime': '2021-08-21 08:35:29',
#    'isDelete': False,
#    'isTop': False,
#    'userImageUrl': 'storage.360buyimg.com/i.imageUpload/6373706c30303031343039343431323438393832_sma.jpg',
#    'topped': 0,
#    'replies': [],
#    'replyCount': 19,
#    'score': 5,
#    'imageStatus': 1,
#    'usefulVoteCount': 42,
#    'userClient': 4,
#    'discussionId': 953628683,
#    'imageCount': 6,
#    'anonymousFlag': 1,
#    'plusAvailable': 201,
#    'mobileVersion': '10.1.0',
#    'images': [{'id': 1522349839,
#      'imgUrl': '//img30.360buyimg.com/n0/s128x96_jfs/t1/189070/21/19404/81667/61204a4bE3d7ffc17/cc858ec46dc93775.jpg',
#      'imgTitle': '',
#      'status': 0},
#     {'id': 1522349840,
#      'imgUrl': '//img30.360buyimg.com/n0/s128x96_jfs/t1/200630/14/2818/71701/61204a4cEccb7d8c2/b53779648ab82754.jpg',
#      'imgTitle': '',
#      'status': 0},
#     {'id': 1522349841,
#      'imgUrl': '//img30.360buyimg.com/n0/s128x96_jfs/t1/191617/5/19114/99711/61204a4dE23d174db/c1fbbb557eadc6b0.jpg',
#      'imgTitle': '',
#      'status': 0},
#     {'id': 1522349842,
#      'imgUrl': '//img30.360buyimg.com/n0/s128x96_jfs/t1/197110/29/4227/91136/61204a4eE6800b015/460615187a6a2a62.jpg',
#      'imgTitle': '',
#      'status': 0},
#     {'id': 1522349843,
#      'imgUrl': '//img30.360buyimg.com/n0/s128x96_jfs/t1/181628/20/20265/68164/61204a4fE3b42823c/58b9bc1c7ffb3ee4.jpg',
#      'imgTitle': '',
#      'status': 0},
#     {'id': 1522349844,
#      'imgUrl': '//img30.360buyimg.com/n0/s128x96_jfs/t1/192476/5/19190/88068/61204a50Ef8092be9/3bc34d888e9d7206.jpg',
#      'imgTitle': '',
#      'status': 0}],
#    'videos': [{'id': 1522349845,
#      'mainUrl': 'https://jvod.300hu.com/img/2021/92715629/1/img2.jpg',
#      'videoHeight': 1280,
#      'videoWidth': 720,
#      'videoLength': 12,
#      'videoTitle': '',
#      'videoUrl': 610258540,
#      'videoId': 610258540,
#      'status': 0,
#      'remark': 'https://jvod.300hu.com/vod/product/910bd105-b456-4095-a723-9601e71b2739/269f38cb9b094d42bcdcb408362576e1.mp4?source=2&h265=h265/18799/3dfac264e3a54cbc83a291390c53feb3.mp4'}],
#    'mergeOrderStatus': 2,
#    'productColor': 'G304 无线游戏鼠标 黑色',
#    'productSize': '',
#    'textIntegral': 20,
#    'imageIntegral': 20,
#    'extMap': {'buyCount': 3},
#    'status': 1,
#    'referenceId': '7571300',
#    'referenceTime': '2021-08-05 14:17:50',
#    'nickname': 'c***0',
#    'replyCount2': 23,
#    'userImage': 'storage.360buyimg.com/i.imageUpload/6373706c30303031343039343431323438393832_sma.jpg',
#    'orderId': 0,
#    'integral': 40,
#    'productSales': '[]',
#    'referenceImage': 'jfs/t1/123274/27/28867/41832/638727faE566582ab/343b659a360659d9.jpg',
#    'referenceName': '罗技（G）G304 LIGHTSPEED无线鼠标 游戏鼠标 轻质便携 绝地求生FPS鼠标英雄联盟LOL吃鸡 生日礼物 白色',
#    'firstCategory': 670,
#    'secondCategory': 686,
#    'thirdCategory': 690,
#    'aesPin': None,
#    'days': 16,
#    'afterDays': 0},
#   {'id': 15850710940,
#    'guid': '61853b1f2cfb27bc685ee2f0bbada1f4',
#    'content': '轻便好用，反应敏捷，特别是点击区比较大，按起来舒服。前后的快捷键也比较清脆。体积和重量比旁边的m720好很多，因为体积小、重量轻，所以快速点击和操作反应快，打游戏比办公更适合，特别是手比较大的。',
#    'creationTime': '2021-06-22 12:55:14',
#    'isDelete': False,
#    'isTop': False,
#    'userImageUrl': 'misc.360buyimg.com/user/myjd-2015/css/i/peisong.jpg',
#    'topped': 0,
#    'replies': [],
#    'replyCount': 4,
#    'score': 5,
#    'imageStatus': 1,
#    'usefulVoteCount': 18,
#    'userClient': 2,
#    'discussionId': 925757484,
#    'imageCount': 5,
#    'anonymousFlag': 1,
#    'plusAvailable': 201,
#    'mobileVersion': '10.0.2',
#    'images': [{'id': 1470627095,
#      'imgUrl': '//img30.360buyimg.com/n0/s128x96_jfs/t1/173604/3/16030/134454/60d16d31Ea2735f64/ee02d68800fdc23d.jpg',
#      'imgTitle': '',
#      'status': 0},
#     {'id': 1470627096,
#      'imgUrl': '//img30.360buyimg.com/n0/s128x96_jfs/t1/179340/14/10663/142630/60d16d31Ee8809082/e9acfcc426062076.jpg',
#      'imgTitle': '',
#      'status': 0},
#     {'id': 1470627097,
#      'imgUrl': '//img30.360buyimg.com/n0/s128x96_jfs/t1/188569/7/9692/131052/60d16d31E446473f5/18c19141b949e508.jpg',
#      'imgTitle': '',
#      'status': 0},
#     {'id': 1470627098,
#      'imgUrl': '//img30.360buyimg.com/n0/s128x96_jfs/t1/181442/11/10580/125342/60d16d31E262b7744/6056039bac9f03ce.jpg',
#      'imgTitle': '',
#      'status': 0},
#     {'id': 1470627099,
#      'imgUrl': '//img30.360buyimg.com/n0/s128x96_jfs/t1/173477/20/15999/134814/60d16d31Ee769cf89/e5c4e8d7e4cf0e8f.jpg',
#      'imgTitle': '',
#      'status': 0}],
#    'videos': [{'id': 1470627100,
#      'mainUrl': 'https://jvod.300hu.com/img/2021/83685265/1/img2.jpg',
#      'videoHeight': 1280,
#      'videoWidth': 960,
#      'videoLength': 12,
#      'videoTitle': '',
#      'videoUrl': 585314664,
#      'videoId': 585314664,
#      'status': 0,
#      'remark': 'https://jvod.300hu.com/vod/product/f8765c89-9e84-47eb-a559-c4c4f3bcbdbb/702d0121e44149c7a23a752500df12b3.mp4?source=2&h265=h265/18799/124865bb337b45c6ba5d20d6b64355cc.mp4'}],
#    'mergeOrderStatus': 2,
#    'productColor': 'G304 无线游戏鼠标 黑色',
#    'productSize': '',
#    'textIntegral': 40,
#    'imageIntegral': 40,
#    'extMap': {'buyCount': 1},
#    'status': 1,
#    'referenceId': '7571300',
#    'referenceTime': '2021-06-17 21:50:00',
#    'nickname': 'w***s',
#    'replyCount2': 5,
#    'userImage': 'misc.360buyimg.com/user/myjd-2015/css/i/peisong.jpg',
#    'orderId': 0,
#    'integral': 80,
#    'productSales': '[]',
#    'referenceImage': 'jfs/t1/123274/27/28867/41832/638727faE566582ab/343b659a360659d9.jpg',
#    'referenceName': '罗技（G）G304 LIGHTSPEED无线鼠标 游戏鼠标 轻质便携 绝地求生FPS鼠标英雄联盟LOL吃鸡 生日礼物 白色',
#    'firstCategory': 670,
#    'secondCategory': 686,
#    'thirdCategory': 690,
#    'aesPin': None,
#    'days': 5,
#    'afterDays': 0},
#   {'id': 15833468241,
#    'guid': 'c54e4b5edeb5aafb96a72d296a29c08d',
#    'content': '原来用g502的俗称手臂锻炼健身器，由于桌上线和东西太多影响玩吃鸡，鼠标拖来拖去老容易勾到线，乘这次618活动搞了个无线鼠标，瞬间清爽了，反正都是hero芯片，1毫秒响应，1000的回报率，性价比很高。怕接受芯片放在机器上影响接受，还送了个usb延长线。',
#    'creationTime': '2021-06-19 14:23:03',
#    'isDelete': False,
#    'isTop': False,
#    'userImageUrl': 'misc.360buyimg.com/user/myjd-2015/css/i/peisong.jpg',
#    'topped': 0,
#    'replies': [],
#    'replyCount': 3,
#    'score': 5,
#    'imageStatus': 1,
#    'usefulVoteCount': 13,
#    'userClient': 2,
#    'discussionId': 923484644,
#    'imageCount': 6,
#    'anonymousFlag': 1,
#    'plusAvailable': 201,
#    'mobileVersion': '10.0.4',
#    'images': [{'id': 1466443120,
#      'imgUrl': '//img30.360buyimg.com/n0/s128x96_jfs/t1/190145/26/9150/244562/60cd8d47E4037bb43/99a492c1d109b793.jpg',
#      'imgTitle': '',
#      'status': 0},
#     {'id': 1466443631,
#      'imgUrl': '//img30.360buyimg.com/n0/s128x96_jfs/t1/174794/38/15418/302333/60cd8d46Efc78ca14/863df38ae968c84e.jpg',
#      'imgTitle': '',
#      'status': 0},
#     {'id': 1466443632,
#      'imgUrl': '//img30.360buyimg.com/n0/s128x96_jfs/t1/189166/19/8672/282374/60cd8d46Ea62d87f0/78f41917eac54f46.jpg',
#      'imgTitle': '',
#      'status': 0},
#     {'id': 1466443633,
#      'imgUrl': '//img30.360buyimg.com/n0/s128x96_jfs/t1/194078/8/9011/261117/60cd8d46Ef8dcb6d3/3f48800230a47531.jpg',
#      'imgTitle': '',
#      'status': 0},
#     {'id': 1466443634,
#      'imgUrl': '//img30.360buyimg.com/n0/s128x96_jfs/t1/181915/6/10032/310149/60cd8d46E00b15021/49c812de72abe68f.jpg',
#      'imgTitle': '',
#      'status': 0},
#     {'id': 1466443635,
#      'imgUrl': '//img30.360buyimg.com/n0/s128x96_jfs/t1/174424/14/15468/256998/60cd8d46E607c6c82/bacf7798a1e81241.jpg',
#      'imgTitle': '',
#      'status': 0}],
#    'videos': [{'id': 1466443636,
#      'mainUrl': 'https://jvod.300hu.com/img/2021/83199362/1/img2.jpg',
#      'videoHeight': 1280,
#      'videoWidth': 960,
#      'videoLength': 10,
#      'videoTitle': '',
#      'videoUrl': 583969697,
#      'videoId': 583969697,
#      'status': 0,
#      'remark': 'https://jvod.300hu.com/vod/product/c11589ba-b6e8-4f01-a9d0-996a03c307c3/df54b7d0947a47b2bfedf0010ca48479.mp4?source=2&h265=h265/18799/f8e0a42a455d487b8bb1ba1b627f1c5c.mp4'}],
#    'mergeOrderStatus': 2,
#    'productColor': 'G304 无线游戏鼠标 黑色',
#    'productSize': '',
#    'textIntegral': 40,
#    'imageIntegral': 40,
#    'extMap': {'buyCount': 4},
#    'status': 1,
#    'referenceId': '7571300',
#    'referenceTime': '2021-06-18 10:06:49',
#    'nickname': '宝***悠',
#    'replyCount2': 4,
#    'userImage': 'misc.360buyimg.com/user/myjd-2015/css/i/peisong.jpg',
#    'orderId': 0,
#    'integral': 80,
#    'productSales': '[]',
#    'referenceImage': 'jfs/t1/123274/27/28867/41832/638727faE566582ab/343b659a360659d9.jpg',
#    'referenceName': '罗技（G）G304 LIGHTSPEED无线鼠标 游戏鼠标 轻质便携 绝地求生FPS鼠标英雄联盟LOL吃鸡 生日礼物 白色',
#    'firstCategory': 670,
#    'secondCategory': 686,
#    'thirdCategory': 690,
#    'aesPin': None,
#    'days': 1,
#    'afterDays': 0},
#   {'id': 17032250866,
#    'guid': '1c65e36d7574cfafbe8b6eb407fe7b9b',
#    'content': '紫色很好看，金克丝真棒！我手19cm抓握和指握都很舒服，鼠标轻盈久玩不累，配上7号锂电池加5号转换筒鼠标重心得以居中，玩CF拉*得心应手，助我排位乱杀哈哈',
#    'creationTime': '2022-01-22 21:58:22',
#    'isDelete': False,
#    'isTop': False,
#    'userImageUrl': 'storage.360buyimg.com/i.imageUpload/b5dbb8f1b2bbd0e2b8d631353136313933363830363130_sma.jpg',
#    'topped': 0,
#    'replies': [],
#    'replyCount': 2,
#    'score': 5,
#    'imageStatus': 1,
#    'usefulVoteCount': 1,
#    'userClient': 4,
#    'discussionId': 1035636038,
#    'imageCount': 6,
#    'anonymousFlag': 1,
#    'plusAvailable': 201,
#    'mobileVersion': '10.3.4',
#    'images': [{'id': 1673168327,
#      'imgUrl': '//img30.360buyimg.com/n0/s128x96_jfs/t1/218411/37/11535/177726/61ec0d79E381d2712/b4c46324d04b1393.jpg',
#      'imgTitle': '',
#      'status': 0},
#     {'id': 1673168328,
#      'imgUrl': '//img30.360buyimg.com/n0/s128x96_jfs/t1/86183/21/19965/111745/61ec0d7aEd4de9afb/b4b0399f83f51cec.jpg',
#      'imgTitle': '',
#      'status': 0},
#     {'id': 1673168329,
#      'imgUrl': '//img30.360buyimg.com/n0/s128x96_jfs/t1/221160/13/9457/174964/61ec0d7bEde611cda/08ca5213688e5949.jpg',
#      'imgTitle': '',
#      'status': 0},
#     {'id': 1673168330,
#      'imgUrl': '//img30.360buyimg.com/n0/s128x96_jfs/t1/106281/29/22585/151636/61ec0d7cEeff875ff/b7548c935d0d4db7.jpg',
#      'imgTitle': '',
#      'status': 0},
#     {'id': 1673168331,
#      'imgUrl': '//img30.360buyimg.com/n0/s128x96_jfs/t1/206589/16/15044/159528/61ec0d7dE5d28696f/6b1df0bbe2d8d5dd.jpg',
#      'imgTitle': '',
#      'status': 0},
#     {'id': 1673168332,
#      'imgUrl': '//img30.360buyimg.com/n0/s128x96_jfs/t1/105984/37/21483/153852/61ec0d7eEa83c3b20/d5761fbd200bfb7e.jpg',
#      'imgTitle': '',
#      'status': 0}],
#    'videos': [{'id': 1673168333,
#      'mainUrl': 'https://jvod.300hu.com/img/2022/121607092/1/img2.jpg',
#      'videoHeight': 1280,
#      'videoWidth': 960,
#      'videoLength': 9,
#      'videoTitle': '',
#      'videoUrl': 692244459,
#      'videoId': 692244459,
#      'status': 0,
#      'remark': 'https://jvod.300hu.com/vod/product/1a23b3b8-7b01-46f6-8f25-c7f31f791851/af1a2a1fac7e4be6aba80db732e2b1e3.mp4?source=2&h265=h265/18799/a7fea09789f24b109ae208867599fc07.mp4'}],
#    'mergeOrderStatus': 2,
#    'productColor': '英雄联盟金克丝定制版',
#    'productSize': '',
#    'textIntegral': 20,
#    'imageIntegral': 20,
#    'extMap': {'buyCount': 5},
#    'status': 1,
#    'referenceId': '100016452061',
#    'referenceTime': '2022-01-09 20:04:46',
#    'nickname': '费***I',
#    'replyCount2': 2,
#    'userImage': 'storage.360buyimg.com/i.imageUpload/b5dbb8f1b2bbd0e2b8d631353136313933363830363130_sma.jpg',
#    'orderId': 0,
#    'integral': 40,
#    'productSales': '[]',
#    'referenceImage': 'jfs/t1/123274/27/28867/41832/638727faE566582ab/343b659a360659d9.jpg',
#    'referenceName': '罗技（G）G304 LIGHTSPEED无线鼠标 游戏鼠标 轻质便携 绝地求生FPS鼠标英雄联盟LOL吃鸡 生日礼物 白色',
#    'firstCategory': 670,
#    'secondCategory': 686,
#    'thirdCategory': 690,
#    'aesPin': None,
#    'days': 13,
#    'afterDays': 0},
#   {'id': 16712021715,
#    'guid': '2c3c85279be2ee80c2adc9625a13aaed',
#    'content': '这个鼠标有点点大，适合中大手。网上测评很多我就不说了。说说使用感觉吧。左右按键手感不错。滚轮的切换很方便，无阻泥模式很顺滑，可以滑好久好久。宏功能软件功能很强大。我设置了复制剪切粘贴前进后退。特别好用。',
#    'creationTime': '2021-11-23 21:58:13',
#    'isDelete': False,
#    'isTop': False,
#    'userImageUrl': 'storage.360buyimg.com/i.imageUpload/4b656e6e79305f3031363531343136323636393231_sma.jpg',
#    'topped': 0,
#    'replies': [],
#    'replyCount': 4,
#    'score': 5,
#    'imageStatus': 1,
#    'usefulVoteCount': 4,
#    'userClient': 2,
#    'discussionId': 1003978205,
#    'imageCount': 4,
#    'anonymousFlag': 1,
#    'plusAvailable': 201,
#    'mobileVersion': '10.2.4',
#    'images': [{'id': 1615155680,
#      'imgUrl': '//img30.360buyimg.com/n0/s128x96_jfs/t1/217893/4/5492/203894/619cf374E68704012/c69eb008bd71eb75.jpg',
#      'imgTitle': '',
#      'status': 0},
#     {'id': 1615155681,
#      'imgUrl': '//img30.360buyimg.com/n0/s128x96_jfs/t1/209544/20/10250/130089/619cf374E1b65edc7/b765ca3a75e2ac32.jpg',
#      'imgTitle': '',
#      'status': 0},
#     {'id': 1615155682,
#      'imgUrl': '//img30.360buyimg.com/n0/s128x96_jfs/t1/139991/27/21312/146764/619cf374Ebb2e0b8f/a66b23fa178555b6.jpg',
#      'imgTitle': '',
#      'status': 0},
#     {'id': 1615155683,
#      'imgUrl': '//img30.360buyimg.com/n0/s128x96_jfs/t1/203654/7/16457/117412/619cf374E1a76a5a4/a828a32cb9fa9b12.jpg',
#      'imgTitle': '',
#      'status': 0}],
#    'videos': [{'id': 1615155684,
#      'mainUrl': 'https://jvod.300hu.com/img/2021/110462119/1/img6.jpg',
#      'videoHeight': 1280,
#      'videoWidth': 960,
#      'videoLength': 7,
#      'videoTitle': '',
#      'videoUrl': 659369834,
#      'videoId': 659369834,
#      'status': 0,
#      'remark': 'https://jvod.300hu.com/vod/product/d0649290-10e8-493e-a300-4bf35a4fbca8/524cb0150e5b40b3b21bf562d7a11a9e.mp4?source=2&h265=h265/18799/67668bd582fb4031acab1958b4b31238.mp4'}],
#    'mergeOrderStatus': 2,
#    'productColor': 'G604无线鼠标',
#    'productSize': '',
#    'textIntegral': 40,
#    'imageIntegral': 40,
#    'extMap': {'buyCount': 1},
#    'status': 1,
#    'referenceId': '100008637122',
#    'referenceTime': '2021-10-28 08:04:24',
#    'nickname': 'H***0',
#    'replyCount2': 4,
#    'userImage': 'storage.360buyimg.com/i.imageUpload/4b656e6e79305f3031363531343136323636393231_sma.jpg',
#    'orderId': 0,
#    'integral': 80,
#    'productSales': '[]',
#    'referenceImage': 'jfs/t1/123274/27/28867/41832/638727faE566582ab/343b659a360659d9.jpg',
#    'referenceName': '罗技（G）G304 LIGHTSPEED无线鼠标 游戏鼠标 轻质便携 绝地求生FPS鼠标英雄联盟LOL吃鸡 生日礼物 白色',
#    'firstCategory': 670,
#    'secondCategory': 686,
#    'thirdCategory': 690,
#    'aesPin': None,
#    'days': 26,
#    'afterDays': 0},
#   {'id': 16602554219,
#    'guid': 'b5f2197dac9f4ac88ca732f66afd708d',
#    'content': '目前使用鼠标的手感不错，尤其是侧键非常好用，已经改成了复制粘贴，很方便，下载罗技的软件后可以使用游戏模式，不掉帧，现在使用的续航模式，感觉也不错，够用了',
#    'creationTime': '2021-11-08 22:31:11',
#    'isDelete': False,
#    'isTop': False,
#    'userImageUrl': 'storage.360buyimg.com/i.imageUpload/31373836323931393332355f7031363638363037373930323739_sma.jpg',
#    'topped': 0,
#    'replies': [],
#    'replyCount': 3,
#    'score': 5,
#    'imageStatus': 1,
#    'usefulVoteCount': 2,
#    'userClient': 4,
#    'discussionId': 992447983,
#    'imageCount': 4,
#    'anonymousFlag': 1,
#    'plusAvailable': 201,
#    'mobileVersion': '10.1.6',
#    'images': [{'id': 1594052372,
#      'imgUrl': '//img30.360buyimg.com/n0/s128x96_jfs/t1/168736/40/22891/101451/618934adE6fd70f2f/83bba8290bd1cfe8.jpg',
#      'imgTitle': '',
#      'status': 0},
#     {'id': 1594052373,
#      'imgUrl': '//img30.360buyimg.com/n0/s128x96_jfs/t1/207694/20/8701/81782/618934adEe45a8758/813f9f39b0b606f0.jpg',
#      'imgTitle': '',
#      'status': 0},
#     {'id': 1594052374,
#      'imgUrl': '//img30.360buyimg.com/n0/s128x96_jfs/t1/197146/6/16573/113852/618934aeE2d97b76c/54c146a8cc026913.jpg',
#      'imgTitle': '',
#      'status': 0},
#     {'id': 1594052375,
#      'imgUrl': '//img30.360buyimg.com/n0/s128x96_jfs/t1/205769/12/14538/105983/618934aeEeada06d0/c2276e493ca2a6b0.jpg',
#      'imgTitle': '',
#      'status': 0}],
#    'videos': [{'id': 1594052376,
#      'mainUrl': 'https://jvod.300hu.com/img/2021/107251547/1/img2.jpg',
#      'videoHeight': 1280,
#      'videoWidth': 960,
#      'videoLength': 15,
#      'videoTitle': '',
#      'videoUrl': 650154268,
#      'videoId': 650154268,
#      'status': 0,
#      'remark': 'https://jvod.300hu.com/vod/product/9a19bb90-3517-4703-b168-70fd6c81166a/fcca5bb564cd4cd6ae537a89fda8f624.mp4?source=2&h265=h265/18799/1b656a133f1e479d920cdd32cd222db8.mp4'}],
#    'mergeOrderStatus': 2,
#    'productColor': 'G304 无线游戏鼠标 黑色',
#    'productSize': '',
#    'textIntegral': 40,
#    'imageIntegral': 40,
#    'extMap': {'buyCount': 1},
#    'status': 1,
#    'referenceId': '7571300',
#    'referenceTime': '2021-11-06 10:26:47',
#    'nickname': '正***汉',
#    'replyCount2': 4,
#    'userImage': 'storage.360buyimg.com/i.imageUpload/31373836323931393332355f7031363638363037373930323739_sma.jpg',
#    'orderId': 0,
#    'integral': 80,
#    'productSales': '[]',
#    'referenceImage': 'jfs/t1/123274/27/28867/41832/638727faE566582ab/343b659a360659d9.jpg',
#    'referenceName': '罗技（G）G304 LIGHTSPEED无线鼠标 游戏鼠标 轻质便携 绝地求生FPS鼠标英雄联盟LOL吃鸡 生日礼物 白色',
#    'firstCategory': 670,
#    'secondCategory': 686,
#    'thirdCategory': 690,
#    'aesPin': None,
#    'days': 2,
#    'afterDays': 0},
#   {'id': 17056464507,
#    'guid': 'fb9bb7eafbe4021e4a38a48daccfcb2d',
#    'content': '鼠标很不错，rgb很漂亮，性能优！左右手都合适！而且链接稳定！主要续航爆棚。基本一个月以上都不需要管！大品牌又是！差不多适用任何场景！',
#    'creationTime': '2022-01-26 18:12:25',
#    'isDelete': False,
#    'isTop': False,
#    'userImageUrl': 'storage.360buyimg.com/i.imageUpload/6a645f3636613234643538336336616431343538303439343633333033_sma.jpg',
#    'topped': 0,
#    'replies': [],
#    'replyCount': 8,
#    'score': 5,
#    'imageStatus': 1,
#    'usefulVoteCount': 4,
#    'userClient': 2,
#    'discussionId': 1037583597,
#    'imageCount': 4,
#    'anonymousFlag': 1,
#    'plusAvailable': 201,
#    'mobileVersion': '10.3.4',
#    'images': [{'id': 1676661199,
#      'imgUrl': '//img30.360buyimg.com/n0/s128x96_jfs/t1/207554/6/16617/380217/61f11e88Ecdc391c8/dc4ac71c676585ff.jpg',
#      'imgTitle': '',
#      'status': 0},
#     {'id': 1676661200,
#      'imgUrl': '//img30.360buyimg.com/n0/s128x96_jfs/t1/221998/1/9767/328875/61f11e88E2f6307c0/c01e9dceb4894f0d.jpg',
#      'imgTitle': '',
#      'status': 0},
#     {'id': 1676661201,
#      'imgUrl': '//img30.360buyimg.com/n0/s128x96_jfs/t1/219986/28/11620/372477/61f11e89E9b87c944/ca36e8cf8166a445.jpg',
#      'imgTitle': '',
#      'status': 0},
#     {'id': 1676661202,
#      'imgUrl': '//img30.360buyimg.com/n0/s128x96_jfs/t1/97482/21/21541/383939/61f11e88E3df72371/40a7dca4e8b47e9c.jpg',
#      'imgTitle': '',
#      'status': 0}],
#    'videos': [{'id': 1676661203,
#      'mainUrl': 'https://jvod.300hu.com/img/2022/122138032/1/img2.jpg',
#      'videoHeight': 1280,
#      'videoWidth': 960,
#      'videoLength': 15,
#      'videoTitle': '',
#      'videoUrl': 694100632,
#      'videoId': 694100632,
#      'status': 0,
#      'remark': 'https://jvod.300hu.com/vod/product/4fd94c3e-a5b2-40c4-bb22-cd35f2d2b346/c2f67c1695a0427db1f2ea854bc8057a.mp4?source=2&h265=h265/18799/c7d00cced8fc443790ab5067ab56511a.mp4'}],
#    'mergeOrderStatus': 2,
#    'productColor': 'G903无线鼠标',
#    'productSize': '',
#    'textIntegral': 40,
#    'imageIntegral': 40,
#    'extMap': {'buyCount': 1},
#    'status': 1,
#    'referenceId': '100006806122',
#    'referenceTime': '2022-01-09 21:42:58',
#    'nickname': '****s',
#    'replyCount2': 8,
#    'userImage': 'storage.360buyimg.com/i.imageUpload/6a645f3636613234643538336336616431343538303439343633333033_sma.jpg',
#    'orderId': 0,
#    'integral': 80,
#    'productSales': '[]',
#    'referenceImage': 'jfs/t1/123274/27/28867/41832/638727faE566582ab/343b659a360659d9.jpg',
#    'referenceName': '罗技（G）G304 LIGHTSPEED无线鼠标 游戏鼠标 轻质便携 绝地求生FPS鼠标英雄联盟LOL吃鸡 生日礼物 白色',
#    'firstCategory': 670,
#    'secondCategory': 686,
#    'thirdCategory': 690,
#    'aesPin': None,
#    'days': 17,
#    'afterDays': 0},
#   {'id': 13933002284,
#    'guid': 'd0a28687-78f8-48e2-b60e-e72f66d627ec',
#    'content': '便携度：第一次用自己买的无线鼠标，很喜欢，收纳槽也蛮喜欢的！\n响应速度：看了很多评测，知道这个很厉害，上手了没发现与有线的区别，我不咋玩射击游戏。\n外观颜值：很喜欢成熟的设计，低调而且有内涵。以前买过蝰蛇2013，那个也很喜欢，这个也很好，感觉适合成熟一点的我。握感和大小贴合，还是更喜欢蝰蛇的外形轮廓，捏着更爆满和舒服，这个有一说一。但是2013双击太严重了，修了几次非常失望，自己那会手艺太差，换樱桃黑点换得也不好，太菜了，现在让我弄绝对完美解决。\n耐用度：蝰蛇后面就用了个G100那样的小鼠标，非常喜欢，很耐用和靠谱，后来了解罗技的口碑，觉得舍得买蝰蛇不如买个这样的级别的，不信任蝰蛇了，微动很廉价。这个没有标微动开关次数寿命，那个兄弟产品好像是502标的5000万次，这个不写应该没那么高。我等使用结果吧，如果这么贵的罗技也跟蝰蛇一样半年就双击，我自己换微动，那以后也不信任这个品牌了，还不如蝰蛇自己升级呢。\n舒适度：表层胶垫非常舒服，很喜欢。\n其他特色：我的手是19的样子，不到20。疫情期间用的8年前的JY嗜血狂魔，也是换过修过了，鼠标手了，腱鞘炎很严重，想找个大鼠标让大拇指舒服点，这个不用腕垫的姿势蛮舒服！我也有立式的，打游戏再用这个鼠标。等追评吧',
#    'vcontent': '{$%&便携度：&%$}第一次用自己买的无线鼠标，很喜欢，收纳槽也蛮喜欢的！\n{$%&响应速度：&%$}看了很多评测，知道这个很厉害，上手了没发现与有线的区别，我不咋玩射击游戏。\n{$%&外观颜值：&%$}很喜欢成熟的设计，低调而且有内涵。以前买过蝰蛇2013，那个也很喜欢，这个也很好，感觉适合成熟一点的我。握感和大小贴合，还是更喜欢蝰蛇的外形轮廓，捏着更爆满和舒服，这个有一说一。但是2013双击太严重了，修了几次非常失望，自己那会手艺太差，换樱桃黑点换得也不好，太菜了，现在让我弄绝对完美解决。\n{$%&耐用度：&%$}蝰蛇后面就用了个G100那样的小鼠标，非常喜欢，很耐用和靠谱，后来了解罗技的口碑，觉得舍得买蝰蛇不如买个这样的级别的，不信任蝰蛇了，微动很廉价。这个没有标微动开关次数寿命，那个兄弟产品好像是502标的5000万次，这个不写应该没那么高。我等使用结果吧，如果这么贵的罗技也跟蝰蛇一样半年就双击，我自己换微动，那以后也不信任这个品牌了，还不如蝰蛇自己升级呢。\n{$%&舒适度：&%$}表层胶垫非常舒服，很喜欢。\n{$%&其他特色：&%$}我的手是19的样子，不到20。疫情期间用的8年前的JY嗜血狂魔，也是换过修过了，鼠标手了，腱鞘炎很严重，想找个大鼠标让大拇指舒服点，这个不用腕垫的姿势蛮舒服！我也有立式的，打游戏再用这个鼠标。等追评吧',
#    'creationTime': '2020-03-19 11:46:08',
#    'isDelete': False,
#    'isTop': False,
#    'userImageUrl': 'storage.360buyimg.com/i.imageUpload/62696e313339333139373139303231363439313439313334333430_sma.jpg',
#    'topped': 0,
#    'replies': [],
#    'replyCount': 7,
#    'score': 5,
#    'imageStatus': 1,
#    'usefulVoteCount': 9,
#    'userClient': 4,
#    'discussionId': 698105602,
#    'imageCount': 8,
#    'anonymousFlag': 0,
#    'plusAvailable': 201,
#    'mobileVersion': '',
#    'images': [{'id': 1084206297,
#      'imgUrl': '//img30.360buyimg.com/n0/s128x96_jfs/t1/89936/35/15380/90109/5e72eafeEb3265216/8856468390359601.jpg',
#      'imgTitle': '',
#      'status': 0},
#     {'id': 1084206298,
#      'imgUrl': '//img30.360buyimg.com/n0/s128x96_jfs/t1/98468/33/15567/66271/5e72eafeE5f93a802/986acd9550332e7a.jpg',
#      'imgTitle': '',
#      'status': 0},
#     {'id': 1084206299,
#      'imgUrl': '//img30.360buyimg.com/n0/s128x96_jfs/t1/105615/30/15503/82227/5e72eafeE7f9d77dc/e6bc74c11ba0f9c7.jpg',
#      'imgTitle': '',
#      'status': 0},
#     {'id': 1084206300,
#      'imgUrl': '//img30.360buyimg.com/n0/s128x96_jfs/t1/110577/28/9276/76719/5e72eaffEb8dccf5d/6e35737516802b46.jpg',
#      'imgTitle': '',
#      'status': 0},
#     {'id': 1084206301,
#      'imgUrl': '//img30.360buyimg.com/n0/s128x96_jfs/t1/85330/7/15603/46117/5e72eaffE6bdab433/933f9bbb189d3fe8.jpg',
#      'imgTitle': '',
#      'status': 0},
#     {'id': 1084206302,
#      'imgUrl': '//img30.360buyimg.com/n0/s128x96_jfs/t1/94971/36/15659/45759/5e72eaffEa872b1e1/250b062cdb8f93fe.jpg',
#      'imgTitle': '',
#      'status': 0},
#     {'id': 1084206303,
#      'imgUrl': '//img30.360buyimg.com/n0/s128x96_jfs/t1/97515/18/15664/58637/5e72eb00E5f7d097b/fc7a1f4e42ae110c.jpg',
#      'imgTitle': '',
#      'status': 0},
#     {'id': 1084206304,
#      'imgUrl': '//img30.360buyimg.com/n0/s128x96_jfs/t1/97884/34/15528/42659/5e72eb00E0b1b9110/99871058fc8a6705.jpg',
#      'imgTitle': '',
#      'status': 0}],
#    'videos': [{'id': 1084206305,
#      'mainUrl': 'https://img.300hu.com/4c1f7a6atransbjngwcloud1oss/215b348d292983279685480449/imageSampleSnapshot/1610281882_670757440.100_956.jpg',
#      'videoHeight': 1280,
#      'videoWidth': 720,
#      'videoLength': 9,
#      'videoTitle': '',
#      'videoUrl': 142867992,
#      'videoId': 142867992,
#      'status': 0,
#      'remark': 'https://vod.300hu.com/4c1f7a6atransbjngwcloud1oss/215b348d292983279685480449/v.f30.mp4?source=1&h265=v.f1022_h265.mp4'}],
#    'mergeOrderStatus': 2,
#    'productColor': '【新品首发】G604 无线游戏鼠标',
#    'productSize': '',
#    'textIntegral': 40,
#    'imageIntegral': 40,
#    'extMap': {'buyCount': 2},
#    'status': 1,
#    'referenceId': '100008637122',
#    'referenceTime': '2020-03-18 22:51:05',
#    'nickname': '怎***啊',
#    'replyCount2': 7,
#    'userImage': 'storage.360buyimg.com/i.imageUpload/62696e313339333139373139303231363439313439313334333430_sma.jpg',
#    'orderId': 0,
#    'integral': 80,
#    'productSales': '[]',
#    'referenceImage': 'jfs/t1/123274/27/28867/41832/638727faE566582ab/343b659a360659d9.jpg',
#    'referenceName': '罗技（G）G304 LIGHTSPEED无线鼠标 游戏鼠标 轻质便携 绝地求生FPS鼠标英雄联盟LOL吃鸡 生日礼物 白色',
#    'firstCategory': 670,
#    'secondCategory': 686,
#    'thirdCategory': 690,
#    'aesPin': 'pCtT8ot0Jl3jXNiopglvdXmiD9Dw_AODUHLyejUt_LTOsjy2PEMykU3bR2WU4XGLKSENu-EIJlgHc6vF85EtWw',
#    'days': 1,
#    'afterDays': 0},
#   {'id': 15765859225,
#    'guid': '7ca5e35cf22c914eb240a06ac721a279',
#    'content': '耐用度：罗技大品牌，耐用度自然不在话下！正常使用几年没问题！\n响应速度：性能模式下1000回报率足足够够！FPS拉*，甩狙啥的定位准确！\n便携度：小巧可爱，身高很好！女生用也无敌，不会大！\n外观颜值：高颜值鼠标，模具设计很满意！特别喜欢白色！白＋紫也很不错！\n舒适度：按键反馈的声音清脆，手感很好，使用起来舒适！\n其他特色：200元价位，G304首选！小手，中手特推！入股不亏，YYDS！冲冲冲！',
#    'vcontent': '{$%&耐用度：&%$}罗技大品牌，耐用度自然不在话下！正常使用几年没问题！\n{$%&响应速度：&%$}性能模式下1000回报率足足够够！FPS拉*，甩狙啥的定位准确！\n{$%&便携度：&%$}小巧可爱，身高很好！女生用也无敌，不会大！\n{$%&外观颜值：&%$}高颜值鼠标，模具设计很满意！特别喜欢白色！白＋紫也很不错！\n{$%&舒适度：&%$}按键反馈的声音清脆，手感很好，使用起来舒适！\n{$%&其他特色：&%$}200元价位，G304首选！小手，中手特推！入股不亏，YYDS！冲冲冲！',
#    'creationTime': '2021-06-05 19:20:09',
#    'isDelete': False,
#    'isTop': False,
#    'userImageUrl': 'storage.360buyimg.com/i.imageUpload/53696c766572bcaab6fb31363232313034373733363137_sma.jpg',
#    'topped': 0,
#    'replies': [],
#    'replyCount': 5,
#    'score': 5,
#    'imageStatus': 1,
#    'usefulVoteCount': 17,
#    'userClient': 4,
#    'discussionId': 915562778,
#    'imageCount': 5,
#    'anonymousFlag': 0,
#    'plusAvailable': 201,
#    'mobileVersion': '10.0.2',
#    'images': [{'id': 1452045318,
#      'imgUrl': '//img30.360buyimg.com/n0/s128x96_jfs/t1/192815/20/6614/45850/60bb5de7Ebf98ef64/5286d1b03f9c1a7e.jpg',
#      'imgTitle': '',
#      'status': 0},
#     {'id': 1452045319,
#      'imgUrl': '//img30.360buyimg.com/n0/s128x96_jfs/t1/173942/37/13127/53895/60bb5de8E296e8d3c/20a096ac234afe64.jpg',
#      'imgTitle': '',
#      'status': 0},
#     {'id': 1452045320,
#      'imgUrl': '//img30.360buyimg.com/n0/s128x96_jfs/t1/128503/13/20251/58677/60bb5de8E3228a941/a0912d21d8b2d1a7.jpg',
#      'imgTitle': '',
#      'status': 0},
#     {'id': 1452045321,
#      'imgUrl': '//img30.360buyimg.com/n0/s128x96_jfs/t1/190298/19/6644/57023/60bb5de8E846988b9/0194a5f74c6122b9.jpg',
#      'imgTitle': '',
#      'status': 0},
#     {'id': 1452045322,
#      'imgUrl': '//img30.360buyimg.com/n0/s128x96_jfs/t1/189350/36/6684/46153/60bb5de8E301dc986/de02af17016bdafe.jpg',
#      'imgTitle': '',
#      'status': 0}],
#    'videos': [{'id': 1452045323,
#      'mainUrl': 'https://jvod.300hu.com/img/2021/81042104/1/img2.jpg',
#      'videoHeight': 1280,
#      'videoWidth': 720,
#      'videoLength': 15,
#      'videoTitle': '',
#      'videoUrl': 577996445,
#      'videoId': 577996445,
#      'status': 0,
#      'remark': 'https://jvod.300hu.com/vod/product/b19347a0-49b8-41ec-bd3c-a9cfadf2d5b7/010e5d8cfa584d2ca260efecf9c4fa90.mp4?source=2&h265=h265/18799/16af6d6f554f40fd9cf0774c3fb49570.mp4'}],
#    'mergeOrderStatus': 2,
#    'productColor': 'G304 无线游戏鼠标 白色',
#    'productSize': '',
#    'textIntegral': 20,
#    'imageIntegral': 20,
#    'extMap': {'buyCount': 1},
#    'status': 1,
#    'referenceId': '7784051',
#    'referenceTime': '2021-05-24 18:10:42',
#    'nickname': '谁***幺',
#    'replyCount2': 7,
#    'userImage': 'storage.360buyimg.com/i.imageUpload/53696c766572bcaab6fb31363232313034373733363137_sma.jpg',
#    'orderId': 0,
#    'integral': 40,
#    'productSales': '[]',
#    'referenceImage': 'jfs/t1/123274/27/28867/41832/638727faE566582ab/343b659a360659d9.jpg',
#    'referenceName': '罗技（G）G304 LIGHTSPEED无线鼠标 游戏鼠标 轻质便携 绝地求生FPS鼠标英雄联盟LOL吃鸡 生日礼物 白色',
#    'firstCategory': 670,
#    'secondCategory': 686,
#    'thirdCategory': 690,
#    'aesPin': 'Z1jpuB9YIWG1G3KqAzlzu-rW9WCP71y5qTiRR0gUiwtE7OkhNru1vd5MjoixwkshczqhKVngzgvOhkk_O0YrTg',
#    'days': 12,
#    'afterDays': 0},
#   {'id': 16064121473,
#    'guid': '63ca6ab423b8a83db6cc398762ce9bec',
#    'content': '简直不要太棒了，手感真的很好啊，支持宏，可以拆卸配重，价格也合适，非常喜欢这个鼠标，外观很酷，对得起这个价格，不错不错。',
#    'creationTime': '2021-07-31 15:27:49',
#    'isDelete': False,
#    'isTop': False,
#    'userImageUrl': 'storage.360buyimg.com/i.imageUpload/6a645f3562366138333034386632633631343530353230363334323931_sma.jpg',
#    'topped': 0,
#    'replies': [],
#    'replyCount': 4,
#    'score': 5,
#    'imageStatus': 1,
#    'usefulVoteCount': 1,
#    'userClient': 4,
#    'discussionId': 944029165,
#    'imageCount': 8,
#    'anonymousFlag': 1,
#    'plusAvailable': 103,
#    'mobileVersion': '10.0.10',
#    'images': [{'id': 1504488822,
#      'imgUrl': '//img30.360buyimg.com/n0/s128x96_jfs/t1/176914/1/16993/110412/6104fb71Eba79e213/d70e9579c885ce9b.jpg',
#      'imgTitle': '',
#      'status': 0},
#     {'id': 1504488823,
#      'imgUrl': '//img30.360buyimg.com/n0/s128x96_jfs/t1/196369/35/15935/93096/6104fb72E3e043e6e/031c94834184ffe1.jpg',
#      'imgTitle': '',
#      'status': 0},
#     {'id': 1504488824,
#      'imgUrl': '//img30.360buyimg.com/n0/s128x96_jfs/t1/187285/21/15778/121088/6104fb72E653af530/3e553b4019d25cc3.jpg',
#      'imgTitle': '',
#      'status': 0},
#     {'id': 1504488825,
#      'imgUrl': '//img30.360buyimg.com/n0/s128x96_jfs/t1/190932/21/15841/98033/6104fb73E97e221b0/d44f4f6b1c6db366.jpg',
#      'imgTitle': '',
#      'status': 0},
#     {'id': 1504488826,
#      'imgUrl': '//img30.360buyimg.com/n0/s128x96_jfs/t1/178770/39/16991/86909/6104fb73Eebf50f0c/627593529fe141d4.jpg',
#      'imgTitle': '',
#      'status': 0},
#     {'id': 1504488827,
#      'imgUrl': '//img30.360buyimg.com/n0/s128x96_jfs/t1/186978/24/15837/119045/6104fb74Ee07c5e36/cb2390a7ce41c22b.jpg',
#      'imgTitle': '',
#      'status': 0},
#     {'id': 1504488828,
#      'imgUrl': '//img30.360buyimg.com/n0/s128x96_jfs/t1/186002/24/16741/185267/6104fb74E33ddaff3/6229b265751e83a8.jpg',
#      'imgTitle': '',
#      'status': 0},
#     {'id': 1504488829,
#      'imgUrl': '//img30.360buyimg.com/n0/s128x96_jfs/t1/198219/26/784/73520/6104fb75E19867758/7da2876937651ea8.jpg',
#      'imgTitle': '',
#      'status': 0}],
#    'mergeOrderStatus': 2,
#    'productColor': 'G903 升级HERO传感器',
#    'productSize': '',
#    'textIntegral': 40,
#    'imageIntegral': 40,
#    'extMap': {'buyCount': 1},
#    'status': 1,
#    'referenceId': '100006806122',
#    'referenceTime': '2021-07-30 10:01:34',
#    'nickname': '到***猪',
#    'replyCount2': 7,
#    'userImage': 'storage.360buyimg.com/i.imageUpload/6a645f3562366138333034386632633631343530353230363334323931_sma.jpg',
#    'orderId': 0,
#    'integral': 80,
#    'productSales': '[]',
#    'referenceImage': 'jfs/t1/123274/27/28867/41832/638727faE566582ab/343b659a360659d9.jpg',
#    'referenceName': '罗技（G）G304 LIGHTSPEED无线鼠标 游戏鼠标 轻质便携 绝地求生FPS鼠标英雄联盟LOL吃鸡 生日礼物 白色',
#    'firstCategory': 670,
#    'secondCategory': 686,
#    'thirdCategory': 690,
#    'aesPin': None,
#    'days': 1,
#    'afterDays': 0}],
#  'soType': 5,
#  'csv': 'eid=100^^tagid=ALL^^pid=20018^^sku=7571300^^sversion=1001^^pageSize=1',
#  'imageListCount': 500,
#  'hotCommentTagStatistics': [{'id': 'c3332df4b16c9ec6',
#    'name': '灵活敏捷',
#    'count': 110,
#    'type': 4,
#    'canBeFiltered': True,
#    'stand': 1,
#    'rid': 'c3332df4b16c9ec6',
#    'ckeKeyWordBury': 'eid=100^^tagid=c3332df4b16c9ec6^^pid=20018^^sku=7784051^^sversion=1000^^token=71f0fc7d16b71c1b'},
#   {'id': 'bf8a7e6407288e6d',
#    'name': '方便快捷',
#    'count': 106,
#    'type': 4,
#    'canBeFiltered': True,
#    'stand': 1,
#    'rid': 'bf8a7e6407288e6d',
#    'ckeKeyWordBury': 'eid=100^^tagid=bf8a7e6407288e6d^^pid=20018^^sku=7784051^^sversion=1000^^token=b70165aa6207d793'},
#   {'id': '2df4fdbae69942d8',
#    'name': '倍感舒适',
#    'count': 101,
#    'type': 4,
#    'canBeFiltered': True,
#    'stand': 1,
#    'rid': '2df4fdbae69942d8',
#    'ckeKeyWordBury': 'eid=100^^tagid=2df4fdbae69942d8^^pid=20018^^sku=7784051^^sversion=1000^^token=c8831b3443597cce'},
#   {'id': '71421dc5a2ce1ba6',
#    'name': '小巧可爱',
#    'count': 81,
#    'type': 4,
#    'canBeFiltered': True,
#    'stand': 1,
#    'rid': '71421dc5a2ce1ba6',
#    'ckeKeyWordBury': 'eid=100^^tagid=71421dc5a2ce1ba6^^pid=20018^^sku=7784051^^sversion=1000^^token=12a1fa5875cc77a2'},
#   {'id': '2a2422ee9d1f7dfc',
#    'name': '反应灵敏',
#    'count': 79,
#    'type': 4,
#    'canBeFiltered': True,
#    'stand': 1,
#    'rid': '2a2422ee9d1f7dfc',
#    'ckeKeyWordBury': 'eid=100^^tagid=2a2422ee9d1f7dfc^^pid=20018^^sku=7784051^^sversion=1000^^token=aebc450212035937'},
#   {'id': '2487c0f9e595f04d',
#    'name': '手感一流',
#    'count': 75,
#    'type': 4,
#    'canBeFiltered': True,
#    'stand': 1,
#    'rid': '2487c0f9e595f04d',
#    'ckeKeyWordBury': 'eid=100^^tagid=2487c0f9e595f04d^^pid=20018^^sku=7784051^^sversion=1000^^token=7b7ee8c7789438af'},
#   {'id': 'b1ed9e915aec5abe',
#    'name': '十分大气',
#    'count': 62,
#    'type': 4,
#    'canBeFiltered': True,
#    'stand': 1,
#    'rid': 'b1ed9e915aec5abe',
#    'ckeKeyWordBury': 'eid=100^^tagid=b1ed9e915aec5abe^^pid=20018^^sku=7784051^^sversion=1000^^token=577cb0170940e4cf'},
#   {'id': '40ed463383d1f34d',
#    'name': '尺寸合适',
#    'count': 50,
#    'type': 4,
#    'canBeFiltered': True,
#    'stand': 1,
#    'rid': '40ed463383d1f34d',
#    'ckeKeyWordBury': 'eid=100^^tagid=40ed463383d1f34d^^pid=20018^^sku=7784051^^sversion=1000^^token=90823b57757fbb1e'},
#   {'id': 'b903fb07c2ddcb06',
#    'name': '质量上乘',
#    'count': 29,
#    'type': 4,
#    'canBeFiltered': True,
#    'stand': 1,
#    'rid': 'b903fb07c2ddcb06',
#    'ckeKeyWordBury': 'eid=100^^tagid=b903fb07c2ddcb06^^pid=20018^^sku=7784051^^sversion=1000^^token=6bab42f5259a8ed3'},
#   {'id': '3304683f1c383716',
#    'name': '声音清亮',
#    'count': 27,
#    'type': 4,
#    'canBeFiltered': True,
#    'stand': 1,
#    'rid': '3304683f1c383716',
#    'ckeKeyWordBury': 'eid=100^^tagid=3304683f1c383716^^pid=20018^^sku=7784051^^sversion=1000^^token=1f468f81ac42ba9d'},
#   {'id': 'e62bf087db98fc82',
#    'name': '结实耐用',
#    'count': 26,
#    'type': 4,
#    'canBeFiltered': True,
#    'stand': 1,
#    'rid': 'e62bf087db98fc82',
#    'ckeKeyWordBury': 'eid=100^^tagid=e62bf087db98fc82^^pid=20018^^sku=7784051^^sversion=1000^^token=fb8850dcf04901d1'}],
#  'testId': 'cmt',
#  'vTagStatistics': None,
#  'maxPage': 100,
#  'productCommentSummary': {'skuId': 7784051,
#   'averageScore': 5,
#   'defaultGoodCount': 0,
#   'defaultGoodCountStr': '100万+',
#   'commentCount': 0,
#   'commentCountStr': '100万+',
#   'goodCount': 0,
#   'goodCountStr': '27万+',
#   'goodRate': 0.98,
#   'goodRateShow': 98,
#   'generalCount': 0,
#   'generalCountStr': '2500+',
#   'generalRate': 0.012,
#   'generalRateShow': 1,
#   'poorCount': 0,
#   'poorCountStr': '2300+',
#   'poorRate': 0.008,
#   'poorRateShow': 1,
#   'videoCount': 0,
#   'videoCountStr': '2700+',
#   'afterCount': 0,
#   'afterCountStr': '3600+',
#   'showCount': 0,
#   'showCountStr': '4.8万+',
#   'oneYear': 0,
#   'sensitiveBook': 0,
#   'fixCount': 49310,
#   'plusCount': 0,
#   'plusCountStr': '0',
#   'buyerShow': 0,
#   'poorRateStyle': 1,
#   'generalRateStyle': 2,
#   'goodRateStyle': 147,
#   'installRate': 0,
#   'productId': 7784051,
#   'score1Count': 2331,
#   'score2Count': 632,
#   'score3Count': 1919,
#   'score4Count': 4190,
#   'score5Count': 220563},
#  'productAttr': None}

# %%
jd["comments"][0]["content"]
# Out:
# '无线鼠标真心好，没有了线的烦恼，移动不受限制。\n罗技品牌很实在，性价比很高，鼠标轻巧，定位准确，手感舒适。\n连接很稳定，没有什么延迟的感觉，。\n我用来竞技游戏比502强，没有编程不影响。'

# %%
#打印评论信息
j=1
for i in jd['comments']:
    print(str(j)+"、"+i['content'])
    j+=1
# Out:
# 1、无线鼠标真心好，没有了线的烦恼，移动不受限制。
# 罗技品牌很实在，性价比很高，鼠标轻巧，定位准确，手感舒适。
# 连接很稳定，没有什么延迟的感觉，。
# 我用来竞技游戏比502强，没有编程不影响。
# 2、轻便好用，反应敏捷，特别是点击区比较大，按起来舒服。前后的快捷键也比较清脆。体积和重量比旁边的m720好很多，因为体积小、重量轻，所以快速点击和操作反应快，打游戏比办公更适合，特别是手比较大的。
# 3、原来用g502的俗称手臂锻炼健身器，由于桌上线和东西太多影响玩吃鸡，鼠标拖来拖去老容易勾到线，乘这次618活动搞了个无线鼠标，瞬间清爽了，反正都是hero芯片，1毫秒响应，1000的回报率，性价比很高。怕接受芯片放在机器上影响接受，还送了个usb延长线。
# 4、紫色很好看，金克丝真棒！我手19cm抓握和指握都很舒服，鼠标轻盈久玩不累，配上7号锂电池加5号转换筒鼠标重心得以居中，玩CF拉*得心应手，助我排位乱杀哈哈
# 5、这个鼠标有点点大，适合中大手。网上测评很多我就不说了。说说使用感觉吧。左右按键手感不错。滚轮的切换很方便，无阻泥模式很顺滑，可以滑好久好久。宏功能软件功能很强大。我设置了复制剪切粘贴前进后退。特别好用。
# 6、目前使用鼠标的手感不错，尤其是侧键非常好用，已经改成了复制粘贴，很方便，下载罗技的软件后可以使用游戏模式，不掉帧，现在使用的续航模式，感觉也不错，够用了
# 7、鼠标很不错，rgb很漂亮，性能优！左右手都合适！而且链接稳定！主要续航爆棚。基本一个月以上都不需要管！大品牌又是！差不多适用任何场景！
# 8、便携度：第一次用自己买的无线鼠标，很喜欢，收纳槽也蛮喜欢的！
# 响应速度：看了很多评测，知道这个很厉害，上手了没发现与有线的区别，我不咋玩射击游戏。
# 外观颜值：很喜欢成熟的设计，低调而且有内涵。以前买过蝰蛇2013，那个也很喜欢，这个也很好，感觉适合成熟一点的我。握感和大小贴合，还是更喜欢蝰蛇的外形轮廓，捏着更爆满和舒服，这个有一说一。但是2013双击太严重了，修了几次非常失望，自己那会手艺太差，换樱桃黑点换得也不好，太菜了，现在让我弄绝对完美解决。
# 耐用度：蝰蛇后面就用了个G100那样的小鼠标，非常喜欢，很耐用和靠谱，后来了解罗技的口碑，觉得舍得买蝰蛇不如买个这样的级别的，不信任蝰蛇了，微动很廉价。这个没有标微动开关次数寿命，那个兄弟产品好像是502标的5000万次，这个不写应该没那么高。我等使用结果吧，如果这么贵的罗技也跟蝰蛇一样半年就双击，我自己换微动，那以后也不信任这个品牌了，还不如蝰蛇自己升级呢。
# 舒适度：表层胶垫非常舒服，很喜欢。
# 其他特色：我的手是19的样子，不到20。疫情期间用的8年前的JY嗜血狂魔，也是换过修过了，鼠标手了，腱鞘炎很严重，想找个大鼠标让大拇指舒服点，这个不用腕垫的姿势蛮舒服！我也有立式的，打游戏再用这个鼠标。等追评吧
# 9、耐用度：罗技大品牌，耐用度自然不在话下！正常使用几年没问题！
# 响应速度：性能模式下1000回报率足足够够！FPS拉*，甩狙啥的定位准确！
# 便携度：小巧可爱，身高很好！女生用也无敌，不会大！
# 外观颜值：高颜值鼠标，模具设计很满意！特别喜欢白色！白＋紫也很不错！
# 舒适度：按键反馈的声音清脆，手感很好，使用起来舒适！
# 其他特色：200元价位，G304首选！小手，中手特推！入股不亏，YYDS！冲冲冲！
# 10、简直不要太棒了，手感真的很好啊，支持宏，可以拆卸配重，价格也合适，非常喜欢这个鼠标，外观很酷，对得起这个价格，不错不错。

# %%
content = []  #存放评价

# %%
def crawler(url):    
    req=re.get(url ,timeout=50,headers=headers)  # 获取网页信息
    jd=json.loads(req.text.lstrip("fetchJSON_comment98vv375(").rstrip(");"))  #先把不用的内容去掉，再用json库解析
    for i in jd['comments']:
        content.append(i['content'])
#爬取自营T490s型号i7-8565U的评论
for i in range(50):
    url="https://club.jd.com/comment/productPageComments.action?callback=fetchJSON_comment98&productId=7784051&score=0&sortType=5&page={}&pageSize=10&isShadowSku=0&fold=1".format(i)
    crawler(url)
print(content)
# Out:
# ['无线鼠标真心好，没有了线的烦恼，移动不受限制。\n罗技品牌很实在，性价比很高，鼠标轻巧，定位准确，手感舒适。\n连接很稳定，没有什么延迟的感觉，。\n我用来竞技游戏比502强，没有编程不影响。', '轻便好用，反应敏捷，特别是点击区比较大，按起来舒服。前后的快捷键也比较清脆。体积和重量比旁边的m720好很多，因为体积小、重量轻，所以快速点击和操作反应快，打游戏比办公更适合，特别是手比较大的。', '原来用g502的俗称手臂锻炼健身器，由于桌上线和东西太多影响玩吃鸡，鼠标拖来拖去老容易勾到线，乘这次618活动搞了个无线鼠标，瞬间清爽了，反正都是hero芯片，1毫秒响应，1000的回报率，性价比很高。怕接受芯片放在机器上影响接受，还送了个usb延长线。', '紫色很好看，金克丝真棒！我手19cm抓握和指握都很舒服，鼠标轻盈久玩不累，配上7号锂电池加5号转换筒鼠标重心得以居中，玩CF拉*得心应手，助我排位乱杀哈哈', '这个鼠标有点点大，适合中大手。网上测评很多我就不说了。说说使用感觉吧。左右按键手感不错。滚轮的切换很方便，无阻泥模式很顺滑，可以滑好久好久。宏功能软件功能很强大。我设置了复制剪切粘贴前进后退。特别好用。', '目前使用鼠标的手感不错，尤其是侧键非常好用，已经改成了复制粘贴，很方便，下载罗技的软件后可以使用游戏模式，不掉帧，现在使用的续航模式，感觉也不错，够用了', '鼠标很不错，rgb很漂亮，性能优！左右手都合适！而且链接稳定！主要续航爆棚。基本一个月以上都不需要管！大品牌又是！差不多适用任何场景！', '便携度：第一次用自己买的无线鼠标，很喜欢，收纳槽也蛮喜欢的！\n响应速度：看了很多评测，知道这个很厉害，上手了没发现与有线的区别，我不咋玩射击游戏。\n外观颜值：很喜欢成熟的设计，低调而且有内涵。以前买过蝰蛇2013，那个也很喜欢，这个也很好，感觉适合成熟一点的我。握感和大小贴合，还是更喜欢蝰蛇的外形轮廓，捏着更爆满和舒服，这个有一说一。但是2013双击太严重了，修了几次非常失望，自己那会手艺太差，换樱桃黑点换得也不好，太菜了，现在让我弄绝对完美解决。\n耐用度：蝰蛇后面就用了个G100那样的小鼠标，非常喜欢，很耐用和靠谱，后来了解罗技的口碑，觉得舍得买蝰蛇不如买个这样的级别的，不信任蝰蛇了，微动很廉价。这个没有标微动开关次数寿命，那个兄弟产品好像是502标的5000万次，这个不写应该没那么高。我等使用结果吧，如果这么贵的罗技也跟蝰蛇一样半年就双击，我自己换微动，那以后也不信任这个品牌了，还不如蝰蛇自己升级呢。\n舒适度：表层胶垫非常舒服，很喜欢。\n其他特色：我的手是19的样子，不到20。疫情期间用的8年前的JY嗜血狂魔，也是换过修过了，鼠标手了，腱鞘炎很严重，想找个大鼠标让大拇指舒服点，这个不用腕垫的姿势蛮舒服！我也有立式的，打游戏再用这个鼠标。等追评吧', '耐用度：罗技大品牌，耐用度自然不在话下！正常使用几年没问题！\n响应速度：性能模式下1000回报率足足够够！FPS拉*，甩狙啥的定位准确！\n便携度：小巧可爱，身高很好！女生用也无敌，不会大！\n外观颜值：高颜值鼠标，模具设计很满意！特别喜欢白色！白＋紫也很不错！\n舒适度：按键反馈的声音清脆，手感很好，使用起来舒适！\n其他特色：200元价位，G304首选！小手，中手特推！入股不亏，YYDS！冲冲冲！', '简直不要太棒了，手感真的很好啊，支持宏，可以拆卸配重，价格也合适，非常喜欢这个鼠标，外观很酷，对得起这个价格，不错不错。', '心心念了好久罗技的G903 终于到手了\n响应速度：响应非常的快 dpi也够高\n便携度：很方便携带 一只鼠标一个接收器足矣\n外观颜值：最喜欢g903的外观非常漂亮\n舒适度：放在手里很舒服 非常时候喜欢用大鼠标的用户', '种草种了两年 攒够京豆等到双十一除草 价格稍微满意 罗技这款G903鼠标太爽了 颜值 做工 灵敏度完美 一直在毒蝰终极版反复横跳 最终选择G903 果然没失望 京东快递和售后一直是我选择的重要因素', '活动购买的鼠标终于到了，开心?。谢谢京东快递，很快就送到了。鼠标打开后，把加重块放了，先给他充个电。手感很好，质感也不错。前面一直用的502，这个是个无线的。非常期待，后面的使用体验。谢谢商家，活动力度很大。点个赞。', '这个鼠标非常的好用，而且有无限蓝牙延长线，你可以接收，信号非常的好，用起来很方便，难以压手，要配合逻辑自带的APP，可以调节dpi，玩游戏没有延迟，不卡顿非常的好用。', '按键很舒服，按键比罗技的办公鼠标好用多了。左右手都可。滑轮也很棒。\n买回来用了大概一个月都没充过电，纯办公用，很耐用。\n耐用度：好\n响应速度：快，舒适，尤其是滑轮，办公看很长的表格时很快很方便\n外观颜值：?。不过可以更炫酷?彩灯可以更多些?\n舒适度：终于有能承托手掌的鼠标。平时的鼠标太小了。性别女', '响应速度：玩游戏绝对感觉不到延迟，也没有断连，绝对是利器。\n便携度：很小巧，没带出去，家用。\n外观颜值：颜值很高，像一种蛋壳。\n舒适度：用着非常舒适，手感很好，不管是游戏办公都行，万能的，搭配轻一点的锂电池，绝佳，建议别用送的电池，太重了。\n其他特色：鼠标驱动功能很丰富。\n耐用度：除了滚轮比较脆弱，其它方面很耐用。', '用的还不错，反应很灵敏。', '响应速度：很快\n便携度：不错 收纳仓里有 2.4 G 收纳槽\n外观颜值：白色款颜值很高\n舒适度：小手抓握趴握都可以 很舒服\n其他特色：整体性很好 和 G102 体验大致差不多 无线鼠标就是没有束缚 随便滑', '罗技G903无线鼠标颜值非常高，性价比非常好。鼠标的做工精致，外观设计非常霸气硬朗结实。手感好，灵敏度也非常高。响应度好，没有发现任何延迟，滑轮灵敏度也非常棒。鼠标小巧精致，便于携带。京东服务态度好，配送及时。', '普通版的和kda版的都买了，白色贴画是真的漂亮！真的特别适合办公使用，家里还是一直用着老古董有线502，5 6年了还是稳定发挥！质量杠杠滴！超赞！', '最早入坑是G102，最近寻思着换个新鼠标试试，挑了半天，看上了这款，也算是旗舰型号了。大小适中，比102大 手感属于适应了就很爽的类型，手用着也不累。电池耐久度也不错。外观也很酷炫。就是一般不用加配重块，加了是真的重。', '买来办公用的，办公操作手感好，偶尔打个游戏也很不错，该买其它颜色的，这款我估计用不了多久就各种颜色了，手感轻盈，按击声适中，四星半吧', '罗技的产品就是好，质量很好。果然没有让我失望，之前用巨硬的4000，非常耗电，所以换了罗技G304。据说一颗电池可以用8个月，现在一个月了，一点电都没掉。非常节能。随时想用就用，不在纠结。', '鼠标的手感很棒，适合160的小手抓握，无名指与大拇指夹住鼠标的侧面，刚好可以轻抬鼠标平移快速放下，作微量调整，适合moba和rts类微操游戏，自由无限，释放自我的感觉真好！', '耐用度：很好用，之前就买过这款\n响应速度：很快速，第二次回购\n便携度：很轻便\n外观颜值：一级棒，黑武士\n舒适度：按键反馈棒\n其他特色：性价比很高。就是需要一定品控保证。\n这是我再次回购的，一个以前用于工作，代码和工程很棒，用了就回不去廉价鼠标了。', '大品牌的质量一如既往地值得信赖，滑动顺畅，定位精准，微动开关按压舒适，有轻微的咔嗒声，不影响其他人。各个键程较短，回弹反馈明显。4档DPI调节，滚轮间隔明显。包装自带连接线和电池，有线无线自由选择。你永远可以信任京东物流，当天下单，隔日送达，非常好的一次购物体验。', '罗技鼠标键盘在每一个买电脑配件的少年都是一个过不去的坎。618趁着优惠，赶紧入手，是正品，包装也非常的好，没有破损，质量也是没得说，材质结实，手感好，紫色颜色非常好看，304性价比很高，值得购买', '左键按下去段位清晰回弹力度恰到好处，采样器居中，移动轨迹定位会很准确，千万不能买偏置的，脚贴覆盖全面，滑动流畅，滑动迅速准确。\n后来的hero引擎终于不飘了，替换掉原来的蝰蛇后感觉非常不错，这是第二只g304。', '打算买来办公用的，拿到手真的超级喜欢，手感非常好，轻重刚好适合，磨砂手感防滑，按键也很舒服，不带灯也很适合办公用，玩游戏应该也非常舒服，宝藏鼠标。', '很好用 之前的鼠标用的习惯了 换了这个鼠标 本以为要熟悉一段时间 还好 很容易上手 很喜欢 作为过渡期的鼠标 简单不花哨 推荐', '耐用度：耐用度肯定不担心 游戏鼠标肯定会比办公的好\n响应速度：响应也可以 打游戏嘛 还这么贵\n便携度：便携无敌 这包装看着都舒服 便携无敌\n外观颜值：黑色加rgb简直无敌\n舒适度：手感很好\n其他特色：买了好多 送给打游戏的朋友 价格还是很实惠的', '这款鼠标设计很棒！经典！握持感特别好！圆润丝滑，超级喜欢！下次再买键鼠类产品还得买这种专业的设备，体验感更好！强烈推荐！冲鸭！', '现有GPW，G903我第一款买的是gpw因为别人推荐，用了一个月之后体验很轻而且续航也是非常的好的但是功能没有那么多，随后我看了推荐买了款903，用了一段时间后发现要不gpw好用一点点，因为我的手比较大比较胖903就非常的适合我 刚能很强 侧键也是很多的 续航也是杠杠的 very nice?', '颜值很高，重量也适中，下了G hub的软件，设置快捷按键和宏方便多了，材质手感很舒服，大小尺寸正合适，但是按键比较轻，所有按键很容易就按下去了，比较容易误按，可能是因为之前的鼠标按键比较重的原因，需要适应一段时间真的是一分钱一分货，很满意的一次 ...

# %%
f=open("3.txt","w",encoding="utf-8")
f.writelines(content)
f.close()
