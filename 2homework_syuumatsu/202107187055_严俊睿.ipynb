# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['font.sans-serif']=['SimHei']
plt.rcParams['axes.unicode_minus']=False

# %%
data=pd.read_csv('O2O数据.csv',
           parse_dates=['Date_received','Date'])

# %%
# 先假定所有用户都是普通用户
## 没有领优惠券，过来消费： 普通用户（-1）
data['label']=-1
## 领了优惠券，15天以内过来消费：正（1）
true_index=(data['Date']-data['Date_received']).dt.days<=15
data.loc[true_index,'label']=1
## 领了优惠券，领了优惠券没消费：负（0）
False_index2=(data['Date_received'].notnull()&data['Date'].isnull())
## 领了优惠券，过了15天后来消费：负（0）
False_index1=(data['Date']-data['Date_received']).dt.days>15
data.loc[(False_index1|False_index2),'label']=0

# %%
# 用户距离存在空值
data['Distance'].isnull().sum()
# 对空值进行填充
#例1：直接对控制进行赋值
data.loc[data['Distance'].isnull(),'Distance']=data['Distance'].mean()
#例2：利用函数填充一个数
data['Distance'].fillna(value=data['Distance'].mean())
#例3：利用相邻数据进行填充
data['Distance'].fillna(method='ffill',  # bfill
                       inplace=False)
# Out:
# 0          0.0
# 1          1.0
# 2          0.0
# 3          0.0
# 4          0.0
#           ...
# 1048570    1.0
# 1048571    1.0
# 1048572    1.0
# 1048573    1.0
# 1048574    1.0
# Name: Distance, Length: 1048575, dtype: float64

# %%
# 两种优惠券变换
def fun(i):
    if ':' in str(i):
        list1=str(i).split(':')
        return 1-int(list1[1])/int(list1[0])
    elif '.' in str(i):
        return float(i)
    else:
        return 1
data['Discount_rate_new']=data['Discount_rate'].apply(fun)

# %%
coupon_popu=data[['Coupon_id','label']].groupby('Coupon_id').agg(lambda x: sum(x==1)/len(x))
coupon_popu.columns=['coupon_popu']
# 把求的结果拼回去
data=pd.merge(data,coupon_popu,
             left_on='Coupon_id',right_index=True,
             how='left')

# %%
user_get=data[['User_id','Coupon_id']].groupby('User_id').agg(lambda x: sum(x.notnull()))
user_get.columns=['user_get']
data=pd.merge(data,user_get,
             left_on='User_id',right_index=True,
             how='left')

# %% [markdown]
# ### 作业1：统计各用户 label 为1的数量

# %%
user_label1=data[['User_id','label']].groupby('User_id').agg(lambda x: sum(x==1))
user_label1.columns=['user_label1']
data=pd.merge(data,user_label1,
             left_on='User_id',right_index=True,
             how='left')
user_label1
# Out:
#          user_label1
# User_id
# 4                  0
# 35                 0
# 64                 0
# 144                0
# 147                0
# ...              ...
# 7360928            1
# 7360952            0
# 7360961            0
# 7360966            0
# 7361024            0
#
# [323087 rows x 1 columns]

# %%
merchant_popu=data[['Merchant_id','Coupon_id','label']].groupby('Merchant_id').agg({
                                            'label':lambda x:sum(x==1),
                                            'Coupon_id':lambda x: sum(x.notnull())})
merchant_popu['merchant_popu']=merchant_popu['label']/merchant_popu['Coupon_id']
data=pd.merge(data,merchant_popu[['merchant_popu']],
             left_on='Merchant_id',right_index=True,
             how='left')

# %%
UM_used=data[['User_id','Merchant_id','label']].groupby(['User_id','Merchant_id']).agg(
                                                            lambda x: sum(x==1))
UM_used.columns=['UM_used']
data=pd.merge(data,UM_used,
             left_on=['User_id','Merchant_id'],
            right_index=True,
             how='left')

# %% [markdown]
# ### 作业2：用户在商家领取的优惠券数

# %%
data
# Out:
#          User_id  Merchant_id  Coupon_id Discount_rate  Distance  \
# 0        1439408         2632        NaN           NaN       0.0
# 1        1439408         4663    11002.0     150:20:00       1.0
# 2        1439408         2632     8591.0         20:01       0.0
# 3        1439408         2632     1078.0         20:01       0.0
# 4        1439408         2632     8591.0         20:01       0.0
# ...          ...          ...        ...           ...       ...
# 1048570  5186127         4043     3996.0      30:05:00       1.0
# 1048571  5186127         4043     3996.0      30:05:00       1.0
# 1048572  5186127         4043        NaN           NaN       1.0
# 1048573  5186127         4043        NaN           NaN       1.0
# 1048574  5186127         4043        NaN           NaN       1.0
#
#         Date_received       Date  label  Discount_rate_new  coupon_popu  \
# 0                 NaT 2016-02-17     -1           1.000000          NaN
# 1          2016-05-28        NaT      0           0.866667     0.001727
# 2          2016-02-17        NaT      0           0.950000     0.000000
# 3          2016-03-19        NaT      0           0.950000     0.000000
# 4          2016-06-13        NaT      0           0.950000     0.000000
# ...               ...        ...    ...                ...          ...
# 1048570    2016-02-03 2016-02-10      1           0.833333     0.222857
# 1048571    2016-02-12        NaT      0           0.833333     0.222857
# 1048572           NaT 2016-05-30     -1           1.000000          NaN
# 1048573           NaT 2016-05-01     -1           1.000000          NaN
# 1048574           NaT 2016-04-08     -1           1.000000          NaN
#
#          user_get  user_label1  merchant_popu  UM_used
# 0               5            0       0.000000        0
# 1               5            0       0.004378        0
# 2               5            0       0.000000        0
# 3               5            0       0.000000        0
# 4               5            0       0.000000        0
# ...           ...          ...            ...      ...
# 1048570         2            1       0.045272        1
# 1048571         2            1       0.045272        1
# 1048572         2            1       0.045272        1
# 1048573         2            1       0.045272        1
# 1048574         2            1       0.045272        1
#
# [1048575 rows x 14 columns]

# %%
user_M_get=data[['User_id','Merchant_id','label']].groupby(['User_id','Merchant_id']).count()
user_M_get
# Out:
#                      label
# User_id Merchant_id
# 4       1433             1
#         1469             1
# 35      3381             4
# 64      2146             1
# 144     1553             1
# ...                    ...
# 7360928 3532             7
# 7360952 3403             1
# 7360961 3621             1
# 7360966 3381             1
# 7361024 1433             1
#
# [550972 rows x 1 columns]

# %%
user_M_get.columns=['user_M_get']
data=pd.merge(data,user_M_get,
             left_on=['User_id','Merchant_id'],right_index=True,
             how='left')

# %% [markdown]
# ### 作业3：用户在商家消费的次数

# %%
data['labelX']=0
## 普通消费日期
False_index2X=(data['Date'].notnull()&data['Coupon_id'].isnull())
## 用优惠券消费日期
False_index1X=(data['Date'].notnull()&data['Coupon_id'].notnull())
data.loc[(False_index1X|False_index2X),'labelX']=1

# %%
user_M_C=data[['User_id','Merchant_id','labelX']].groupby(['User_id','Merchant_id']).agg(lambda x: sum(x==1))
user_M_C
# Out:
#                      labelX
# User_id Merchant_id
# 4       1433              0
#         1469              0
# 35      3381              0
# 64      2146              0
# 144     1553              0
# ...                     ...
# 7360928 3532              6
# 7360952 3403              0
# 7360961 3621              0
# 7360966 3381              0
# 7361024 1433              0
#
# [550972 rows x 1 columns]

# %%
user_M_C.columns=['user_M_C']
data=pd.merge(data,user_M_C,
             left_on=['User_id','Merchant_id'],right_index=True,
             how='left')

# %%
data
# Out:
#          User_id  Merchant_id  Coupon_id Discount_rate  Distance  \
# 0        1439408         2632        NaN           NaN       0.0
# 1        1439408         4663    11002.0     150:20:00       1.0
# 2        1439408         2632     8591.0         20:01       0.0
# 3        1439408         2632     1078.0         20:01       0.0
# 4        1439408         2632     8591.0         20:01       0.0
# ...          ...          ...        ...           ...       ...
# 1048570  5186127         4043     3996.0      30:05:00       1.0
# 1048571  5186127         4043     3996.0      30:05:00       1.0
# 1048572  5186127         4043        NaN           NaN       1.0
# 1048573  5186127         4043        NaN           NaN       1.0
# 1048574  5186127         4043        NaN           NaN       1.0
#
#         Date_received       Date  label  Discount_rate_new  coupon_popu  \
# 0                 NaT 2016-02-17     -1           1.000000          NaN
# 1          2016-05-28        NaT      0           0.866667     0.001727
# 2          2016-02-17        NaT      0           0.950000     0.000000
# 3          2016-03-19        NaT      0           0.950000     0.000000
# 4          2016-06-13        NaT      0           0.950000     0.000000
# ...               ...        ...    ...                ...          ...
# 1048570    2016-02-03 2016-02-10      1           0.833333     0.222857
# 1048571    2016-02-12        NaT      0           0.833333     0.222857
# 1048572           NaT 2016-05-30     -1           1.000000          NaN
# 1048573           NaT 2016-05-01     -1           1.000000          NaN
# 1048574           NaT 2016-04-08     -1           1.000000          NaN
#
#          user_get  user_label1  merchant_popu  UM_used  user_M_get  labelX  \
# 0               5            0       0.000000        0           6       1
# 1               5            0       0.004378        0           1       0
# 2               5            0       0.000000        0           6       0
# 3               5            0       0.000000        0           6       0
# 4               5            0       0.000000        0           6       0
# ...           ...          ...            ...      ...         ...     ...
# 1048570         2            1       0.045272        1           6       1
# 1048571         2            1       0.045272        1           6       0
# 1048572         2            1       0.045272        1           6       1
# 1048573         2            1       0.045272        1           6       1
# 1048574         2            1       0.045272        1           6       1
#
#          user_M_C
# 0               3
# 1               0
# 2               3
# 3               3
# 4               3
# ...           ...
# 1048570         5
# 1048571         5
# 1048572         5
# 1048573         5
# 1048574         5
#
# [1048575 rows x 17 columns]

# %%
data['label'].value_counts()
n=10
data_T=data[data['label']==1].sample(n)

# %% [markdown]
# ### 抽样负样本

# %%
data_F=data[data['label']==0].sample(n)
data_F
# Out:
#          User_id  Merchant_id  Coupon_id Discount_rate  Distance  \
# 788480   2941104          450     8555.0      30:05:00       4.0
# 638326   7200632         5717     8192.0         20:05      10.0
# 511073   6989107         2709     2840.0     100:10:00       6.0
# 143500    895251          760     2418.0      30:05:00       2.0
# 992420   4880542         2934     5686.0      30:05:00       3.0
# 638351   3078588         3381     1807.0     300:30:00       2.0
# 38263    2213792         6485     9407.0     100:10:00       1.0
# 922860   7081654          913     9759.0         20:01       0.0
# 1035038  7232962         5341      111.0      30:05:00       0.0
# 927951   3547501         2146    11173.0     100:10:00       3.0
#
#         Date_received Date  label  Discount_rate_new  coupon_popu  user_get  \
# 788480     2016-01-27  NaT      0           0.833333     0.004062         4
# 638326     2016-05-28  NaT      0           0.750000     0.012409         1
# 511073     2016-01-28  NaT      0           0.900000     0.001546         5
# 143500     2016-06-05  NaT      0           0.833333     0.038473         3
# 992420     2016-03-23  NaT      0           0.833333     0.157312         3
# 638351     2016-01-26  NaT      0           0.900000     0.004864         3
# 38263      2016-02-03  NaT      0           0.900000     0.009310         5
# 922860     2016-05-20  NaT      0           0.950000     0.257143         2
# 1035038    2016-02-04  NaT      0           0.833333     0.056352         1
# 927951     2016-01-29  NaT      0           0.900000     0.002488         2
#
#          user_label1  merchant_popu  UM_used  user_M_get  labelX  user_M_C
# 788480             0       0.016409        0           1       0         0
# 638326             0       0.013521        0           1       0         0
# 511073             0       0.003169        0           1       0         0
# 143500             0       0.056495        0           1       0         0
# 992420             0       0.157312        0           4       0         3
# 638351             0       0.011912        0           2       0         1
# 38263              0       0.233439        0           2       0         1
# 922860             0       0.259259        0           4       0         2
# 1035038            0       0.115744        0           1       0         0
# 927951             0       0.003152        0           1       0         0

# %% [markdown]
# ### 合并抽样的正负样本

# %%
data_clear=pd.concat([data_T,data_F])
data_clear
# Out:
#          User_id  Merchant_id  Coupon_id Discount_rate   Distance  \
# 775445    811687         2934     5686.0      30:05:00   8.000000
# 510831   4646191         4579     1708.0         20:05   1.000000
# 793160   3852984         7555     9871.0      30:05:00   8.000000
# 967979   4694002         1631    13663.0         20:05   2.000000
# 666165   1843189         5265     6117.0     100:20:00   2.362526
# 335392   6672026         1169     4627.0      50:20:00   0.000000
# 1011933  4429090         5341      111.0      30:05:00   0.000000
# 294371   4666565         3403    11214.0         20:05   0.000000
# 906843   2597665         6885     3105.0         10:01   1.000000
# 187626   2670230         8181     1560.0         20:05   0.000000
# 788480   2941104          450     8555.0      30:05:00   4.000000
# 638326   7200632         5717     8192.0         20:05  10.000000
# 511073   6989107         2709     2840.0     100:10:00   6.000000
# 143500    895251          760     2418.0      30:05:00   2.000000
# 992420   4880542         2934     5686.0      30:05:00   3.000000
# 638351   3078588         3381     1807.0     300:30:00   2.000000
# 38263    2213792         6485     9407.0     100:10:00   1.000000
# 922860   7081654          913     9759.0         20:01   0.000000
# 1035038  7232962         5341      111.0      30:05:00   0.000000
# 927951   3547501         2146    11173.0     100:10:00   3.000000
#
#         Date_received       Date  label  Discount_rate_new  coupon_popu  \
# 775445     2016-03-22 2016-03-27      1           0.833333     0.157312
# 510831     2016-03-22 2016-03-24      1           0.750000     0.271845
# 793160     2016-04-06 2016-04-09      1           0.833333     0.019321
# 967979     2016-03-27 2016-04-02      1           0.750000     0.218182
# 666165     2016-05-07 2016-05-07      1           0.800000     0.500000
# 335392     2016-02-16 2016-02-16      1           0.600000     0.382239
# 1011933    2016-01-31 2016-02-04      1           0.833333     0.056352
# 294371     2016-06-01 2016-06-06      1           0.750000     0.300000
# 906843     2016-01-10 2016-01-22      1           0.900000     0.222222
# 187626     2016-03-26 2016-04-02      1           0.750000     0.317308
# 788480     2016-01-27        NaT      0           0.833333     0.004062
# 638326     2016-05-28        NaT      0           0.750000     0.012409
# 511073     2016-01-28        NaT      0           0.900000     0.001546
# 143500     2016-06-05        NaT      0           0.833333     0.038473
# 992420     2016-03-23        NaT      0           0.833333     0.157312
# 638351     2016-01-26        NaT      0           0.900000     0.004864
# 38263      2016-02-03        NaT      0           0.900000     0.009310
# 922860     2016-05-20        NaT      0           0.950000     0.257143
# 1035038    2016-02-04        NaT      0           0.833333     0.056352
# 927951     2016-01-29        NaT      0           0.900000     0.002488
#
#          user_get  user_label1  merchant_popu  UM_used  user_M_get  labelX  \
# 775445          2            1       0.157312        1           2       1
# 510831          7            3       0.094308        3          41       1
# 793160          3            1       0.044739        1           3       1
# 967979          1            1       0.218182        1           2       1
# 666165          1            1       0.117647        1           1       1
# 335392          1            1       0.061086        1           1       1
# 1011933         8            1       0.115744        1           3       1
# 294371          4            2       0.372385        2          14       1
# 906843          6            2       0.164835        2           6       1
# 187626          5            1       0.068085        1           5       1
# 788480          4            0       0.016409        0           1       0
# 638326          1            0       0.013521        0           1       0
# 511073          5            0       0.003169        0           1       0
# 143500          3            0       0.056495        0           1       0
# 992420          3            0       0.157312        0           4       0
# 638351          3            0       0.011912        0           2       0
# 38263           5            0       0.233439        0           2       0
# 922860          2            0       0.259259        0           4       0
# 1035038         1            0       0.115744        0           1       0
# 927951          2            0       0.003152        0           1       0
#
#          user_M_C
# 775445          2
# 510831         41
# 793160          3
# 967979          2
# 666165          1
# 335392          1
# 1011933         1
# 294371         14
# 906843          3
# 187626          2
# 788480          0
# 638326          0
# 511073          0
# 143500          0
# 992420          3
# 638351          1
# 38263           1
# 922860          2
# 1035038         0
# 927951          0

# %% [markdown]
# ### 预测

# %%
data_clear.columns
# Out:
# Index(['User_id', 'Merchant_id', 'Coupon_id', 'Discount_rate', 'Distance',
#        'Date_received', 'Date', 'label', 'Discount_rate_new', 'coupon_popu',
#        'user_get', 'user_label1', 'merchant_popu', 'UM_used', 'user_M_get',
#        'labelX', 'user_M_C'],
#       dtype='object')

# %%
X = data_clear[['Distance','Discount_rate_new','coupon_popu','user_get','user_label1','merchant_popu','UM_used','user_M_get','user_M_C']]
Y = data_clear['label']

# %% [markdown]
# # 数据标准化

# %%
from sklearn.preprocessing import Normalizer
X = Normalizer().fit_transform(X)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,)

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier()
model.fit(X_train,Y_train)
# Out:
# DecisionTreeClassifier()

# %%
from sklearn.metrics import roc_auc_score,confusion_matrix,classification_report
pre = model.predict_proba(X_test)
auc = roc_auc_score(Y_test,pre[:,1])
print(auc)
pre = model.predict(X_test)
con_mat = confusion_matrix(Y_test,pre)
print(con_mat)
print(classification_report(Y_test,pre))
# Out:
# 1.0
# [[1 0]
#  [0 3]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         1
#            1       1.00      1.00      1.00         3
#
#     accuracy                           1.00         4
#    macro avg       1.00      1.00      1.00         4
# weighted avg       1.00      1.00      1.00         4
