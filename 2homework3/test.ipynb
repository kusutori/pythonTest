# %% [markdown]
# # 百货商店客户细分

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
plt.rcParams['font.sans-serif'] = ['SimHei']
plt.rcParams['axes.unicode_minus'] = False

# %% [markdown]
# ## 流水数据

# %%
# 读数据
sales = pd.read_csv('data/sales.csv', encoding='utf-8')
sales
# Out:
# C:\Users\31815\AppData\Local\Temp\ipykernel_19952\2579366754.py:2: DtypeWarning: Columns (0,11) have mixed types. Specify dtype option on import or set low_memory=False.
#   sales = pd.read_csv('data/sales.csv', encoding='utf-8')
#              会员卡号                  消费产生的时间      商品编码  销售数量   商品售价    消费金额  \
# 0        1be1e3fe  2015-01-01 00:05:41.593  f09c9303     1  290.0  270.20
# 1        1be1e3fe  2015-01-01 00:05:41.593  f09c9303     1  325.0  302.80
# 2        1be1e3fe  2015-01-01 00:05:41.593  f09c9303     1  195.0  181.80
# 3        1be1e3fe  2015-01-01 00:05:41.593  f09c9303     1  270.0  251.55
# 4        1be1e3fe  2015-01-01 00:05:41.593  f09c9303     2  245.0  456.55
# ...           ...                      ...       ...   ...    ...     ...
# 1893527  607c7cde  2018-01-03 21:38:15.343  c483e08b     1  200.0  200.00
# 1893528  220c0564  2018-01-03 21:41:53.140  cd93b1ca     1    1.0    1.00
# 1893529  220c0564  2018-01-03 21:41:53.140  cd93b1ca     1  490.0  490.00
# 1893530  220c0564  2018-01-03 21:41:53.140  cd93b1ca     1  280.0  280.00
# 1893531  220c0564  2018-01-03 21:41:53.140  cd93b1ca     1  880.0  880.00
#
#              商品名称  此次消费的会员积分  收银机号   单据号    柜组编码        柜组名称
# 0        兰芝化妆品正价瓶     270.20     6  25bb  8077.0         兰芝柜
# 1        兰芝化妆品正价瓶     302.80     6  25bb  8077.0         兰芝柜
# 2        兰芝化妆品正价瓶     181.80     6  25bb  8077.0         兰芝柜
# 3        兰芝化妆品正价瓶     251.55     6  25bb  8077.0         兰芝柜
# 4        兰芝化妆品正价瓶     456.55     6  25bb  8077.0         兰芝柜
# ...           ...        ...   ...   ...     ...         ...
# 1893527   植村秀眉笔4g     200.00    91  3d84  8156.0  Shu Uemura
# 1893528   爱慕内衣正价件       1.00   264  7cd8  4332.0       Aimer
# 1893529   爱慕内衣正价件     490.00   264  7cd8  4332.0       Aimer
# 1893530   爱慕内衣正价件     280.00   264  7cd8  4332.0       Aimer
# 1893531   爱慕内衣正价件     880.00   264  7cd8  4332.0       Aimer
#
# [1893532 rows x 12 columns]

# %%
# 把时间转换成时间格式
sales['消费产生的时间'] = pd.to_datetime(sales['消费产生的时间'])

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1893532 entries, 0 to 1893531
# Data columns (total 12 columns):
#  #   Column     Dtype
# ---  ------     -----
#  0   会员卡号       object
#  1   消费产生的时间    datetime64[ns]
#  2   商品编码       object
#  3   销售数量       int64
#  4   商品售价       float64
#  5   消费金额       float64
#  6   商品名称       object
#  7   此次消费的会员积分  float64
#  8   收银机号       int64
#  9   单据号        object
#  10  柜组编码       float64
#  11  柜组名称       object
# dtypes: datetime64[ns](1), float64(4), int64(2), object(5)
# memory usage: 173.4+ MB

# %% [markdown]
# ## 会员信息

# %%
# 会员信息
userinfo = pd.read_excel('data/userinfo.xlsx',parse_dates=['出生日期','登记时间'])
userinfo
# Out:
#             会员卡号                 出生日期   性别                    登记时间
# 0       c68b20b4  2002-11-02 00:00:00  0.0 2013-05-11 00:00:00.000
# 1       1ca15332                  NaN  0.0 2004-11-04 16:31:52.436
# 2       a37cc182  1967-02-17 00:00:00  0.0 2004-12-31 21:24:34.216
# 3       2ab88539  1982-06-01 00:00:00  0.0 2010-11-19 00:00:00.000
# 4       b4c77269  1964-02-05 00:00:00  0.0 2007-12-14 00:00:00.000
# ...          ...                  ...  ...                     ...
# 194755  a97474e0                  NaN  NaN                     NaT
# 194756  4e14ad22                  NaN  0.0 2013-08-30 00:00:00.000
# 194757  f20299a8                  NaN  NaN 2014-03-18 00:00:00.000
# 194758  a3a27f12  1973-01-10 00:00:00  0.0 2015-03-10 00:00:00.000
# 194759  a03cc001  1964-08-11 00:00:00  0.0 2010-08-09 00:00:00.000
#
# [194760 rows x 4 columns]

# %%
# 日期处理
userinfo['出生日期'] = pd.to_datetime(userinfo['出生日期'], errors='coerce')

# %%
userinfo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 194760 entries, 0 to 194759
# Data columns (total 4 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   会员卡号    194760 non-null  object
#  1   出生日期    160553 non-null  datetime64[ns]
#  2   性别      185325 non-null  float64
#  3   登记时间    182076 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), float64(1), object(1)
# memory usage: 5.9+ MB

# %% [markdown]
# ## 清洗会员数据

# %% [markdown]
# ### 存在部分会员登记时间早于会员出生时间

# %%
# 提取出生日期大于登记日期的数据
time1=(userinfo['登记时间']-userinfo['出生日期']).dt.days
part1_user = userinfo.loc[time1>0,:]
part1_user.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 154163 entries, 0 to 194759
# Data columns (total 4 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   会员卡号    154163 non-null  object
#  1   出生日期    154163 non-null  datetime64[ns]
#  2   性别      153176 non-null  float64
#  3   登记时间    154163 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), float64(1), object(1)
# memory usage: 5.9+ MB

# %% [markdown]
# ### 存在缺失值

# %%
part1_user.dropna(inplace=True)
# Out:
# C:\Users\31815\AppData\Local\Temp\ipykernel_19952\1540930359.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   part1_user.dropna(inplace=True)

# %% [markdown]
# ### 删除重复会员

# %%
part1_user.drop_duplicates(inplace=True)
# Out:
# C:\Users\31815\AppData\Local\Temp\ipykernel_19952\741189198.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   part1_user.drop_duplicates(inplace=True)

# %%
part1_user.shape
# Out:
# (153176, 4)

# %% [markdown]
# ## 清洗流水数据

# %% [markdown]
# ### 删除退货订单

# %%
# 删除销售数量为0的数据
sales = sales.loc[sales['销售数量']>0,:]
sales
# Out:
#              会员卡号                 消费产生的时间      商品编码  销售数量   商品售价    消费金额  \
# 0        1be1e3fe 2015-01-01 00:05:41.593  f09c9303     1  290.0  270.20
# 1        1be1e3fe 2015-01-01 00:05:41.593  f09c9303     1  325.0  302.80
# 2        1be1e3fe 2015-01-01 00:05:41.593  f09c9303     1  195.0  181.80
# 3        1be1e3fe 2015-01-01 00:05:41.593  f09c9303     1  270.0  251.55
# 4        1be1e3fe 2015-01-01 00:05:41.593  f09c9303     2  245.0  456.55
# ...           ...                     ...       ...   ...    ...     ...
# 1893527  607c7cde 2018-01-03 21:38:15.343  c483e08b     1  200.0  200.00
# 1893528  220c0564 2018-01-03 21:41:53.140  cd93b1ca     1    1.0    1.00
# 1893529  220c0564 2018-01-03 21:41:53.140  cd93b1ca     1  490.0  490.00
# 1893530  220c0564 2018-01-03 21:41:53.140  cd93b1ca     1  280.0  280.00
# 1893531  220c0564 2018-01-03 21:41:53.140  cd93b1ca     1  880.0  880.00
#
#              商品名称  此次消费的会员积分  收银机号   单据号    柜组编码        柜组名称
# 0        兰芝化妆品正价瓶     270.20     6  25bb  8077.0         兰芝柜
# 1        兰芝化妆品正价瓶     302.80     6  25bb  8077.0         兰芝柜
# 2        兰芝化妆品正价瓶     181.80     6  25bb  8077.0         兰芝柜
# 3        兰芝化妆品正价瓶     251.55     6  25bb  8077.0         兰芝柜
# 4        兰芝化妆品正价瓶     456.55     6  25bb  8077.0         兰芝柜
# ...           ...        ...   ...   ...     ...         ...
# 1893527   植村秀眉笔4g     200.00    91  3d84  8156.0  Shu Uemura
# 1893528   爱慕内衣正价件       1.00   264  7cd8  4332.0       Aimer
# 1893529   爱慕内衣正价件     490.00   264  7cd8  4332.0       Aimer
# 1893530   爱慕内衣正价件     280.00   264  7cd8  4332.0       Aimer
# 1893531   爱慕内衣正价件     880.00   264  7cd8  4332.0       Aimer
#
# [1866980 rows x 12 columns]

# %% [markdown]
# ### 删除消费金额不为正的订单

# %%
sales = sales.loc[sales['消费金额']>0,:]
sales
# Out:
#              会员卡号                 消费产生的时间      商品编码  销售数量   商品售价    消费金额  \
# 0        1be1e3fe 2015-01-01 00:05:41.593  f09c9303     1  290.0  270.20
# 1        1be1e3fe 2015-01-01 00:05:41.593  f09c9303     1  325.0  302.80
# 2        1be1e3fe 2015-01-01 00:05:41.593  f09c9303     1  195.0  181.80
# 3        1be1e3fe 2015-01-01 00:05:41.593  f09c9303     1  270.0  251.55
# 4        1be1e3fe 2015-01-01 00:05:41.593  f09c9303     2  245.0  456.55
# ...           ...                     ...       ...   ...    ...     ...
# 1893527  607c7cde 2018-01-03 21:38:15.343  c483e08b     1  200.0  200.00
# 1893528  220c0564 2018-01-03 21:41:53.140  cd93b1ca     1    1.0    1.00
# 1893529  220c0564 2018-01-03 21:41:53.140  cd93b1ca     1  490.0  490.00
# 1893530  220c0564 2018-01-03 21:41:53.140  cd93b1ca     1  280.0  280.00
# 1893531  220c0564 2018-01-03 21:41:53.140  cd93b1ca     1  880.0  880.00
#
#              商品名称  此次消费的会员积分  收银机号   单据号    柜组编码        柜组名称
# 0        兰芝化妆品正价瓶     270.20     6  25bb  8077.0         兰芝柜
# 1        兰芝化妆品正价瓶     302.80     6  25bb  8077.0         兰芝柜
# 2        兰芝化妆品正价瓶     181.80     6  25bb  8077.0         兰芝柜
# 3        兰芝化妆品正价瓶     251.55     6  25bb  8077.0         兰芝柜
# 4        兰芝化妆品正价瓶     456.55     6  25bb  8077.0         兰芝柜
# ...           ...        ...   ...   ...     ...         ...
# 1893527   植村秀眉笔4g     200.00    91  3d84  8156.0  Shu Uemura
# 1893528   爱慕内衣正价件       1.00   264  7cd8  4332.0       Aimer
# 1893529   爱慕内衣正价件     490.00   264  7cd8  4332.0       Aimer
# 1893530   爱慕内衣正价件     280.00   264  7cd8  4332.0       Aimer
# 1893531   爱慕内衣正价件     880.00   264  7cd8  4332.0       Aimer
#
# [1861251 rows x 12 columns]

# %% [markdown]
# ## 合并数据

# %%
data = pd.merge(sales,part1_user,how='outer',on='会员卡号')
data
# Out:
#              会员卡号                 消费产生的时间      商品编码  销售数量   商品售价    消费金额  \
# 0        1be1e3fe 2015-01-01 00:05:41.593  f09c9303   1.0  290.0  270.20
# 1        1be1e3fe 2015-01-01 00:05:41.593  f09c9303   1.0  325.0  302.80
# 2        1be1e3fe 2015-01-01 00:05:41.593  f09c9303   1.0  195.0  181.80
# 3        1be1e3fe 2015-01-01 00:05:41.593  f09c9303   1.0  270.0  251.55
# 4        1be1e3fe 2015-01-01 00:05:41.593  f09c9303   2.0  245.0  456.55
# ...           ...                     ...       ...   ...    ...     ...
# 1973746  9e7c711e                     NaT       NaN   NaN    NaN     NaN
# 1973747  5b7c99c6                     NaT       NaN   NaN    NaN     NaN
# 1973748  3f98ac2e                     NaT       NaN   NaN    NaN     NaN
# 1973749  a3a27f12                     NaT       NaN   NaN    NaN     NaN
# 1973750  a03cc001                     NaT       NaN   NaN    NaN     NaN
#
#              商品名称  此次消费的会员积分  收银机号   单据号    柜组编码 柜组名称       出生日期   性别  \
# 0        兰芝化妆品正价瓶     270.20   6.0  25bb  8077.0  兰芝柜        NaT  NaN
# 1        兰芝化妆品正价瓶     302.80   6.0  25bb  8077.0  兰芝柜        NaT  NaN
# 2        兰芝化妆品正价瓶     181.80   6.0  25bb  8077.0  兰芝柜        NaT  NaN
# 3        兰芝化妆品正价瓶     251.55   6.0  25bb  8077.0  兰芝柜        NaT  NaN
# 4        兰芝化妆品正价瓶     456.55   6.0  25bb  8077.0  兰芝柜        NaT  NaN
# ...           ...        ...   ...   ...     ...  ...        ...  ...
# 1973746       NaN        NaN   NaN   NaN     NaN  NaN 1993-06-24  1.0
# 1973747       NaN        NaN   NaN   NaN     NaN  NaN 1979-04-23  1.0
# 1973748       NaN        NaN   NaN   NaN     NaN  NaN 1981-03-02  1.0
# 1973749       NaN        NaN   NaN   NaN     NaN  NaN 1973-01-10  0.0
# 1973750       NaN        NaN   NaN   NaN     NaN  NaN 1964-08-11  0.0
#
#               登记时间
# 0              NaT
# 1              NaT
# 2              NaT
# 3              NaT
# 4              NaT
# ...            ...
# 1973746 2013-08-30
# 1973747 2010-06-14
# 1973748 2013-08-30
# 1973749 2015-03-10
# 1973750 2010-08-09
#
# [1973751 rows x 15 columns]

# %% [markdown]
# ## 删除空数据

# %%
# 提取会员数据
vip = data[data['会员卡号'].notnull()]
vip
# Out:
#              会员卡号                 消费产生的时间      商品编码  销售数量   商品售价    消费金额  \
# 0        1be1e3fe 2015-01-01 00:05:41.593  f09c9303   1.0  290.0  270.20
# 1        1be1e3fe 2015-01-01 00:05:41.593  f09c9303   1.0  325.0  302.80
# 2        1be1e3fe 2015-01-01 00:05:41.593  f09c9303   1.0  195.0  181.80
# 3        1be1e3fe 2015-01-01 00:05:41.593  f09c9303   1.0  270.0  251.55
# 4        1be1e3fe 2015-01-01 00:05:41.593  f09c9303   2.0  245.0  456.55
# ...           ...                     ...       ...   ...    ...     ...
# 1973746  9e7c711e                     NaT       NaN   NaN    NaN     NaN
# 1973747  5b7c99c6                     NaT       NaN   NaN    NaN     NaN
# 1973748  3f98ac2e                     NaT       NaN   NaN    NaN     NaN
# 1973749  a3a27f12                     NaT       NaN   NaN    NaN     NaN
# 1973750  a03cc001                     NaT       NaN   NaN    NaN     NaN
#
#              商品名称  此次消费的会员积分  收银机号   单据号    柜组编码 柜组名称       出生日期   性别  \
# 0        兰芝化妆品正价瓶     270.20   6.0  25bb  8077.0  兰芝柜        NaT  NaN
# 1        兰芝化妆品正价瓶     302.80   6.0  25bb  8077.0  兰芝柜        NaT  NaN
# 2        兰芝化妆品正价瓶     181.80   6.0  25bb  8077.0  兰芝柜        NaT  NaN
# 3        兰芝化妆品正价瓶     251.55   6.0  25bb  8077.0  兰芝柜        NaT  NaN
# 4        兰芝化妆品正价瓶     456.55   6.0  25bb  8077.0  兰芝柜        NaT  NaN
# ...           ...        ...   ...   ...     ...  ...        ...  ...
# 1973746       NaN        NaN   NaN   NaN     NaN  NaN 1993-06-24  1.0
# 1973747       NaN        NaN   NaN   NaN     NaN  NaN 1979-04-23  1.0
# 1973748       NaN        NaN   NaN   NaN     NaN  NaN 1981-03-02  1.0
# 1973749       NaN        NaN   NaN   NaN     NaN  NaN 1973-01-10  0.0
# 1973750       NaN        NaN   NaN   NaN     NaN  NaN 1964-08-11  0.0
#
#               登记时间
# 0              NaT
# 1              NaT
# 2              NaT
# 3              NaT
# 4              NaT
# ...            ...
# 1973746 2013-08-30
# 1973747 2010-06-14
# 1973748 2013-08-30
# 1973749 2015-03-10
# 1973750 2010-08-09
#
# [979211 rows x 15 columns]

# %%
# 删除没有消费的会员数据
Vip_data = vip.dropna()
Vip_data
# Out:
#              会员卡号                 消费产生的时间      商品编码  销售数量    商品售价    消费金额  \
# 301      d8d36575 2015-01-01 00:06:38.313  d313ab1e   1.0  1760.0  1760.0
# 302      d8d36575 2015-01-01 00:06:38.313  d313ab1e   1.0  9072.0  9072.0
# 303      d8d36575 2015-01-01 00:06:38.313  50a2c4f5   1.0  1507.0  1507.0
# 304      d8d36575 2015-01-01 00:06:38.313  50a2c4f5   1.0   899.0   899.0
# 305      d8d36575 2015-01-01 00:06:38.313  d313ab1e   1.0  1960.0  1960.0
# ...           ...                     ...       ...   ...     ...     ...
# 1861290  826ea280 2018-01-03 21:25:16.236  2c276195   1.0   399.0   399.0
# 1861291  dd018e94 2018-01-03 20:32:50.000  84c0c98a   1.0  1679.0  1679.0
# 1861292  69de49e9 2018-01-03 21:08:58.063  88111139   1.0   560.0   560.0
# 1861293  69de49e9 2018-01-03 21:08:58.063  4e727693   1.0   640.0   640.0
# 1861294  69de49e9 2018-01-03 21:08:58.063  1c680610   1.0   550.0   550.0
#
#                     商品名称  此次消费的会员积分   收银机号   单据号    柜组编码            柜组名称  \
# 301           MARYLINGC件    1678.82   10.0  5858  2273.0      MARYLING 柜
# 302           MARYLINGC件    8653.56   10.0  5858  2273.0      MARYLING 柜
# 303          汤普葛罗女鞋活动促销双    1437.49   10.0  5858  8131.0            TOP柜
# 304          汤普葛罗女鞋活动促销双     857.54   10.0  5858  8131.0            TOP柜
# 305           MARYLINGC件    1869.59   10.0  5858  2273.0      MARYLING 柜
# ...                  ...        ...    ...   ...     ...             ...
# 1861290          芭芭麻麻正价件     399.00  205.0  fcd0  2337.0            芭芭麻麻
# 1861291  MO&CO.EDIFIONC件    1679.00  224.0  7cd8  3264.0  MO&CO.EDITION柜
# 1861292    科颜氏高保湿面霜125ml     560.00  102.0  2d09  8186.0    科颜氏(Kiehl's)
# 1861293      科颜氏丰润保湿精华乳.     640.00  102.0  2d09  8186.0    科颜氏(Kiehl's)
# 1861294   科颜氏金盏花爽肤水500ml     550.00  102.0  2d09  8186.0    科颜氏(Kiehl's)
#
#               出生日期   性别                    登记时间
# 301     1973-10-25  0.0 2007-08-12 00:00:00.000
# 302     1973-10-25  0.0 2007-08-12 00:00:00.000
# 303     1973-10-25  0.0 2007-08-12 00:00:00.000
# 304     1973-10-25  0.0 2007-08-12 00:00:00.000
# 305     1973-10-25  0.0 2007-08-12 00:00:00.000
# ...            ...  ...                     ...
# 1861290 1985-02-01  0.0 2017-12-25 19:30:50.746
# 1861291 1989-05-20  0.0 2014-12-24 00:00:00.000
# 1861292 1988-01-04  0.0 2018-01-03 20:41:57.733
# 1861293 1988-01-04  0.0 2018-01-03 20:41:57.733
# 1861294 1988-01-04  0.0 2018-01-03 20:41:57.733
#
# [440058 rows x 15 columns]

# %% [markdown]
# ## 数据暂存

# %% [markdown]
# ## 学习分箱

# %%
today = pd.Timestamp(year=2023,month=2,day=22)
# 第一：计算年龄
data['年龄'] = (today - data['出生日期']).dt.days/365
# 第二：指定区间进行分箱
labels =['未成年','青年','中年','老年']
bins = [0,22,45,60,100]
data['年龄段'] = pd.cut(data['年龄'],bins=bins,labels=labels)
ans = data['年龄段'].value_counts()
plt.figure(figsize=(8,8),facecolor='white')
ans.plot.pie()
# 第三：借助 map，映射成中文信息放到数据中
# Out:
# <Axes: ylabel='年龄段'>

# %% [markdown]
# ## 特征工程

# %% [markdown]
# ### L：入会时长

# %%
Vip_data['入会时长'] = (Vip_data['登记时间'].max()-Vip_data['登记时间']).dt.days
Vip_data
# Out:
# C:\Users\31815\AppData\Local\Temp\ipykernel_19952\2689619908.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Vip_data['入会时长'] = (Vip_data['登记时间'].max()-Vip_data['登记时间']).dt.days
#              会员卡号                 消费产生的时间      商品编码  销售数量    商品售价    消费金额  \
# 301      d8d36575 2015-01-01 00:06:38.313  d313ab1e   1.0  1760.0  1760.0
# 302      d8d36575 2015-01-01 00:06:38.313  d313ab1e   1.0  9072.0  9072.0
# 303      d8d36575 2015-01-01 00:06:38.313  50a2c4f5   1.0  1507.0  1507.0
# 304      d8d36575 2015-01-01 00:06:38.313  50a2c4f5   1.0   899.0   899.0
# 305      d8d36575 2015-01-01 00:06:38.313  d313ab1e   1.0  1960.0  1960.0
# ...           ...                     ...       ...   ...     ...     ...
# 1861290  826ea280 2018-01-03 21:25:16.236  2c276195   1.0   399.0   399.0
# 1861291  dd018e94 2018-01-03 20:32:50.000  84c0c98a   1.0  1679.0  1679.0
# 1861292  69de49e9 2018-01-03 21:08:58.063  88111139   1.0   560.0   560.0
# 1861293  69de49e9 2018-01-03 21:08:58.063  4e727693   1.0   640.0   640.0
# 1861294  69de49e9 2018-01-03 21:08:58.063  1c680610   1.0   550.0   550.0
#
#                     商品名称  此次消费的会员积分   收银机号   单据号    柜组编码            柜组名称  \
# 301           MARYLINGC件    1678.82   10.0  5858  2273.0      MARYLING 柜
# 302           MARYLINGC件    8653.56   10.0  5858  2273.0      MARYLING 柜
# 303          汤普葛罗女鞋活动促销双    1437.49   10.0  5858  8131.0            TOP柜
# 304          汤普葛罗女鞋活动促销双     857.54   10.0  5858  8131.0            TOP柜
# 305           MARYLINGC件    1869.59   10.0  5858  2273.0      MARYLING 柜
# ...                  ...        ...    ...   ...     ...             ...
# 1861290          芭芭麻麻正价件     399.00  205.0  fcd0  2337.0            芭芭麻麻
# 1861291  MO&CO.EDIFIONC件    1679.00  224.0  7cd8  3264.0  MO&CO.EDITION柜
# 1861292    科颜氏高保湿面霜125ml     560.00  102.0  2d09  8186.0    科颜氏(Kiehl's)
# 1861293      科颜氏丰润保湿精华乳.     640.00  102.0  2d09  8186.0    科颜氏(Kiehl's)
# 1861294   科颜氏金盏花爽肤水500ml     550.00  102.0  2d09  8186.0    科颜氏(Kiehl's)
#
#               出生日期   性别                    登记时间  入会时长
# 301     1973-10-25  0.0 2007-08-12 00:00:00.000  3797
# 302     1973-10-25  0.0 2007-08-12 00:00:00.000  3797
# 303     1973-10-25  0.0 2007-08-12 00:00:00.000  3797
# 304     1973-10-25  0.0 2007-08-12 00:00:00.000  3797
# 305     1973-10-25  0.0 2007-08-12 00:00:00.000  3797
# ...            ...  ...                     ...   ...
# 1861290 1985-02-01  0.0 2017-12-25 19:30:50.746     9
# 1861291 1989-05-20  0.0 2014-12-24 00:00:00.000  1106
# 1861292 1988-01-04  0.0 2018-01-03 20:41:57.733     0
# 1861293 1988-01-04  0.0 2018-01-03 20:41:57.733     0
# 1861294 1988-01-04  0.0 2018-01-03 20:41:57.733     0
#
# [440058 rows x 16 columns]

# %% [markdown]
# ### R：最近一次消费距今时长

# %% [markdown]
# #### 第一种方法

# %%
ans = Vip_data[{'会员卡号','消费产生的时间'}].groupby('会员卡号').max() # 最后一次时间的提取 
ans = ans.max()-ans # 计算时间间隔
ans['最近一次消费距今时长'] = ans['消费产生的时间'].dt.days # 提取天数
Vip_data1 = pd.merge(Vip_data,ans,left_on='会员卡号',right_index=True,how='left')
Vip_data1
# Out:
# C:\Users\31815\AppData\Local\Temp\ipykernel_19952\23668682.py:1: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   ans = Vip_data[{'会员卡号','消费产生的时间'}].groupby('会员卡号').max() # 最后一次时间的提取
#              会员卡号               消费产生的时间_x      商品编码  销售数量    商品售价    消费金额  \
# 301      d8d36575 2015-01-01 00:06:38.313  d313ab1e   1.0  1760.0  1760.0
# 302      d8d36575 2015-01-01 00:06:38.313  d313ab1e   1.0  9072.0  9072.0
# 303      d8d36575 2015-01-01 00:06:38.313  50a2c4f5   1.0  1507.0  1507.0
# 304      d8d36575 2015-01-01 00:06:38.313  50a2c4f5   1.0   899.0   899.0
# 305      d8d36575 2015-01-01 00:06:38.313  d313ab1e   1.0  1960.0  1960.0
# ...           ...                     ...       ...   ...     ...     ...
# 1861290  826ea280 2018-01-03 21:25:16.236  2c276195   1.0   399.0   399.0
# 1861291  dd018e94 2018-01-03 20:32:50.000  84c0c98a   1.0  1679.0  1679.0
# 1861292  69de49e9 2018-01-03 21:08:58.063  88111139   1.0   560.0   560.0
# 1861293  69de49e9 2018-01-03 21:08:58.063  4e727693   1.0   640.0   640.0
# 1861294  69de49e9 2018-01-03 21:08:58.063  1c680610   1.0   550.0   550.0
#
#                     商品名称  此次消费的会员积分   收银机号   单据号    柜组编码            柜组名称  \
# 301           MARYLINGC件    1678.82   10.0  5858  2273.0      MARYLING 柜
# 302           MARYLINGC件    8653.56   10.0  5858  2273.0      MARYLING 柜
# 303          汤普葛罗女鞋活动促销双    1437.49   10.0  5858  8131.0            TOP柜
# 304          汤普葛罗女鞋活动促销双     857.54   10.0  5858  8131.0            TOP柜
# 305           MARYLINGC件    1869.59   10.0  5858  2273.0      MARYLING 柜
# ...                  ...        ...    ...   ...     ...             ...
# 1861290          芭芭麻麻正价件     399.00  205.0  fcd0  2337.0            芭芭麻麻
# 1861291  MO&CO.EDIFIONC件    1679.00  224.0  7cd8  3264.0  MO&CO.EDITION柜
# 1861292    科颜氏高保湿面霜125ml     560.00  102.0  2d09  8186.0    科颜氏(Kiehl's)
# 1861293      科颜氏丰润保湿精华乳.     640.00  102.0  2d09  8186.0    科颜氏(Kiehl's)
# 1861294   科颜氏金盏花爽肤水500ml     550.00  102.0  2d09  8186.0    科颜氏(Kiehl's)
#
#               出生日期   性别                    登记时间  入会时长  \
# 301     1973-10-25  0.0 2007-08-12 00:00:00.000  3797
# 302     1973-10-25  0.0 2007-08-12 00:00:00.000  3797
# 303     1973-10-25  0.0 2007-08-12 00:00:00.000  3797
# 304     1973-10-25  0.0 2007-08-12 00:00:00.000  3797
# 305     1973-10-25  0.0 2007-08-12 00:00:00.000  3797
# ...            ...  ...                     ...   ...
# 1861290 1985-02-01  0.0 2017-12-25 19:30:50.746     9
# 1861291 1989-05-20  0.0 2014-12-24 00:00:00.000  1106
# 1861292 1988-01-04  0.0 2018-01-03 20:41:57.733     0
# 1861293 1988-01-04  0.0 2018-01-03 20:41:57.733     0
# 1861294 1988-01-04  0.0 2018-01-03 20:41:57.733     0
#
#                        消费产生的时间_y  最近一次消费距今时长
# 301     280 days 09:12:49.140000         280
# 302     280 days 09:12:49.140000         280
# 303     280 days 09:12:49.140000         280
# 304     280 days 09:12:49.140000         280
# 305     280 days 09:12:49.140000         280
# ...                          ...         ...
# 1861290   0 days 00:02:12.450000           0
# 1861291   0 days 00:54:38.686000           0
# 1861292   0 days 00:18:30.623000           0
# 1861293   0 days 00:18:30.623000           0
# 1861294   0 days 00:18:30.623000           0
#
# [440058 rows x 18 columns]

# %% [markdown]
# #### 第二种方法

# %%
# 计算消费时间
Vip_data['消费时长'] = (Vip_data['消费产生的时间'].max()-Vip_data['消费产生的时间']).dt.days
ans2 = Vip_data[{'会员卡号','消费时长'}].groupby('会员卡号').min()
ans2.columns = ['最近一次消费距今时长']
Vip_data2 = pd.merge(Vip_data,ans2,left_on='会员卡号',right_index=True,how='left')
Vip_data2
# Out:
# C:\Users\31815\AppData\Local\Temp\ipykernel_19952\3137829464.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Vip_data['消费时长'] = (Vip_data['消费产生的时间'].max()-Vip_data['消费产生的时间']).dt.days
# C:\Users\31815\AppData\Local\Temp\ipykernel_19952\3137829464.py:3: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   ans2 = Vip_data[{'会员卡号','消费时长'}].groupby('会员卡号').min()
#              会员卡号                 消费产生的时间      商品编码  销售数量    商品售价    消费金额  \
# 301      d8d36575 2015-01-01 00:06:38.313  d313ab1e   1.0  1760.0  1760.0
# 302      d8d36575 2015-01-01 00:06:38.313  d313ab1e   1.0  9072.0  9072.0
# 303      d8d36575 2015-01-01 00:06:38.313  50a2c4f5   1.0  1507.0  1507.0
# 304      d8d36575 2015-01-01 00:06:38.313  50a2c4f5   1.0   899.0   899.0
# 305      d8d36575 2015-01-01 00:06:38.313  d313ab1e   1.0  1960.0  1960.0
# ...           ...                     ...       ...   ...     ...     ...
# 1861290  826ea280 2018-01-03 21:25:16.236  2c276195   1.0   399.0   399.0
# 1861291  dd018e94 2018-01-03 20:32:50.000  84c0c98a   1.0  1679.0  1679.0
# 1861292  69de49e9 2018-01-03 21:08:58.063  88111139   1.0   560.0   560.0
# 1861293  69de49e9 2018-01-03 21:08:58.063  4e727693   1.0   640.0   640.0
# 1861294  69de49e9 2018-01-03 21:08:58.063  1c680610   1.0   550.0   550.0
#
#                     商品名称  此次消费的会员积分   收银机号   单据号    柜组编码            柜组名称  \
# 301           MARYLINGC件    1678.82   10.0  5858  2273.0      MARYLING 柜
# 302           MARYLINGC件    8653.56   10.0  5858  2273.0      MARYLING 柜
# 303          汤普葛罗女鞋活动促销双    1437.49   10.0  5858  8131.0            TOP柜
# 304          汤普葛罗女鞋活动促销双     857.54   10.0  5858  8131.0            TOP柜
# 305           MARYLINGC件    1869.59   10.0  5858  2273.0      MARYLING 柜
# ...                  ...        ...    ...   ...     ...             ...
# 1861290          芭芭麻麻正价件     399.00  205.0  fcd0  2337.0            芭芭麻麻
# 1861291  MO&CO.EDIFIONC件    1679.00  224.0  7cd8  3264.0  MO&CO.EDITION柜
# 1861292    科颜氏高保湿面霜125ml     560.00  102.0  2d09  8186.0    科颜氏(Kiehl's)
# 1861293      科颜氏丰润保湿精华乳.     640.00  102.0  2d09  8186.0    科颜氏(Kiehl's)
# 1861294   科颜氏金盏花爽肤水500ml     550.00  102.0  2d09  8186.0    科颜氏(Kiehl's)
#
#               出生日期   性别                    登记时间  入会时长  消费时长  最近一次消费距今时长
# 301     1973-10-25  0.0 2007-08-12 00:00:00.000  3797  1098         280
# 302     1973-10-25  0.0 2007-08-12 00:00:00.000  3797  1098         280
# 303     1973-10-25  0.0 2007-08-12 00:00:00.000  3797  1098         280
# 304     1973-10-25  0.0 2007-08-12 00:00:00.000  3797  1098         280
# 305     1973-10-25  0.0 2007-08-12 00:00:00.000  3797  1098         280
# ...            ...  ...                     ...   ...   ...         ...
# 1861290 1985-02-01  0.0 2017-12-25 19:30:50.746     9     0           0
# 1861291 1989-05-20  0.0 2014-12-24 00:00:00.000  1106     0           0
# 1861292 1988-01-04  0.0 2018-01-03 20:41:57.733     0     0           0
# 1861293 1988-01-04  0.0 2018-01-03 20:41:57.733     0     0           0
# 1861294 1988-01-04  0.0 2018-01-03 20:41:57.733     0     0           0
#
# [440058 rows x 18 columns]

# %% [markdown]
# ### M：用户花费的总金额

# %%
ans3 = Vip_data[{'会员卡号','消费时长'}].groupby('会员卡号').sum()
ans3.columns = ['消费总金额']
Vip_data3 = pd.merge(Vip_data2,ans3,left_on='会员卡号',right_index=True,how='left')
Vip_data3
# Out:
# C:\Users\31815\AppData\Local\Temp\ipykernel_19952\899608057.py:1: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   ans3 = Vip_data[{'会员卡号','消费时长'}].groupby('会员卡号').sum()
#              会员卡号                 消费产生的时间      商品编码  销售数量    商品售价    消费金额  \
# 301      d8d36575 2015-01-01 00:06:38.313  d313ab1e   1.0  1760.0  1760.0
# 302      d8d36575 2015-01-01 00:06:38.313  d313ab1e   1.0  9072.0  9072.0
# 303      d8d36575 2015-01-01 00:06:38.313  50a2c4f5   1.0  1507.0  1507.0
# 304      d8d36575 2015-01-01 00:06:38.313  50a2c4f5   1.0   899.0   899.0
# 305      d8d36575 2015-01-01 00:06:38.313  d313ab1e   1.0  1960.0  1960.0
# ...           ...                     ...       ...   ...     ...     ...
# 1861290  826ea280 2018-01-03 21:25:16.236  2c276195   1.0   399.0   399.0
# 1861291  dd018e94 2018-01-03 20:32:50.000  84c0c98a   1.0  1679.0  1679.0
# 1861292  69de49e9 2018-01-03 21:08:58.063  88111139   1.0   560.0   560.0
# 1861293  69de49e9 2018-01-03 21:08:58.063  4e727693   1.0   640.0   640.0
# 1861294  69de49e9 2018-01-03 21:08:58.063  1c680610   1.0   550.0   550.0
#
#                     商品名称  此次消费的会员积分   收银机号   单据号    柜组编码            柜组名称  \
# 301           MARYLINGC件    1678.82   10.0  5858  2273.0      MARYLING 柜
# 302           MARYLINGC件    8653.56   10.0  5858  2273.0      MARYLING 柜
# 303          汤普葛罗女鞋活动促销双    1437.49   10.0  5858  8131.0            TOP柜
# 304          汤普葛罗女鞋活动促销双     857.54   10.0  5858  8131.0            TOP柜
# 305           MARYLINGC件    1869.59   10.0  5858  2273.0      MARYLING 柜
# ...                  ...        ...    ...   ...     ...             ...
# 1861290          芭芭麻麻正价件     399.00  205.0  fcd0  2337.0            芭芭麻麻
# 1861291  MO&CO.EDIFIONC件    1679.00  224.0  7cd8  3264.0  MO&CO.EDITION柜
# 1861292    科颜氏高保湿面霜125ml     560.00  102.0  2d09  8186.0    科颜氏(Kiehl's)
# 1861293      科颜氏丰润保湿精华乳.     640.00  102.0  2d09  8186.0    科颜氏(Kiehl's)
# 1861294   科颜氏金盏花爽肤水500ml     550.00  102.0  2d09  8186.0    科颜氏(Kiehl's)
#
#               出生日期   性别                    登记时间  入会时长  消费时长  最近一次消费距今时长  消费总金额
# 301     1973-10-25  0.0 2007-08-12 00:00:00.000  3797  1098         280  38089
# 302     1973-10-25  0.0 2007-08-12 00:00:00.000  3797  1098         280  38089
# 303     1973-10-25  0.0 2007-08-12 00:00:00.000  3797  1098         280  38089
# 304     1973-10-25  0.0 2007-08-12 00:00:00.000  3797  1098         280  38089
# 305     1973-10-25  0.0 2007-08-12 00:00:00.000  3797  1098         280  38089
# ...            ...  ...                     ...   ...   ...         ...    ...
# 1861290 1985-02-01  0.0 2017-12-25 19:30:50.746     9     0           0      0
# 1861291 1989-05-20  0.0 2014-12-24 00:00:00.000  1106     0           0      0
# 1861292 1988-01-04  0.0 2018-01-03 20:41:57.733     0     0           0      0
# 1861293 1988-01-04  0.0 2018-01-03 20:41:57.733     0     0           0      0
# 1861294 1988-01-04  0.0 2018-01-03 20:41:57.733     0     0           0      0
#
# [440058 rows x 19 columns]

# %% [markdown]
# ### F：用户消费的总次数

# %%
ans4 = Vip_data[{'会员卡号','消费时长'}].groupby('会员卡号').count()
ans4.columns = ['消费次数']
Vip_data4 = pd.merge(Vip_data3,ans4,left_on='会员卡号',right_index=True,how='left')
Vip_data4
# Out:
# C:\Users\31815\AppData\Local\Temp\ipykernel_19952\3401184488.py:1: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   ans4 = Vip_data[{'会员卡号','消费时长'}].groupby('会员卡号').count()
#              会员卡号                 消费产生的时间      商品编码  销售数量    商品售价    消费金额  \
# 301      d8d36575 2015-01-01 00:06:38.313  d313ab1e   1.0  1760.0  1760.0
# 302      d8d36575 2015-01-01 00:06:38.313  d313ab1e   1.0  9072.0  9072.0
# 303      d8d36575 2015-01-01 00:06:38.313  50a2c4f5   1.0  1507.0  1507.0
# 304      d8d36575 2015-01-01 00:06:38.313  50a2c4f5   1.0   899.0   899.0
# 305      d8d36575 2015-01-01 00:06:38.313  d313ab1e   1.0  1960.0  1960.0
# ...           ...                     ...       ...   ...     ...     ...
# 1861290  826ea280 2018-01-03 21:25:16.236  2c276195   1.0   399.0   399.0
# 1861291  dd018e94 2018-01-03 20:32:50.000  84c0c98a   1.0  1679.0  1679.0
# 1861292  69de49e9 2018-01-03 21:08:58.063  88111139   1.0   560.0   560.0
# 1861293  69de49e9 2018-01-03 21:08:58.063  4e727693   1.0   640.0   640.0
# 1861294  69de49e9 2018-01-03 21:08:58.063  1c680610   1.0   550.0   550.0
#
#                     商品名称  此次消费的会员积分   收银机号   单据号    柜组编码            柜组名称  \
# 301           MARYLINGC件    1678.82   10.0  5858  2273.0      MARYLING 柜
# 302           MARYLINGC件    8653.56   10.0  5858  2273.0      MARYLING 柜
# 303          汤普葛罗女鞋活动促销双    1437.49   10.0  5858  8131.0            TOP柜
# 304          汤普葛罗女鞋活动促销双     857.54   10.0  5858  8131.0            TOP柜
# 305           MARYLINGC件    1869.59   10.0  5858  2273.0      MARYLING 柜
# ...                  ...        ...    ...   ...     ...             ...
# 1861290          芭芭麻麻正价件     399.00  205.0  fcd0  2337.0            芭芭麻麻
# 1861291  MO&CO.EDIFIONC件    1679.00  224.0  7cd8  3264.0  MO&CO.EDITION柜
# 1861292    科颜氏高保湿面霜125ml     560.00  102.0  2d09  8186.0    科颜氏(Kiehl's)
# 1861293      科颜氏丰润保湿精华乳.     640.00  102.0  2d09  8186.0    科颜氏(Kiehl's)
# 1861294   科颜氏金盏花爽肤水500ml     550.00  102.0  2d09  8186.0    科颜氏(Kiehl's)
#
#               出生日期   性别                    登记时间  入会时长  消费时长  最近一次消费距今时长  \
# 301     1973-10-25  0.0 2007-08-12 00:00:00.000  3797  1098         280
# 302     1973-10-25  0.0 2007-08-12 00:00:00.000  3797  1098         280
# 303     1973-10-25  0.0 2007-08-12 00:00:00.000  3797  1098         280
# 304     1973-10-25  0.0 2007-08-12 00:00:00.000  3797  1098         280
# 305     1973-10-25  0.0 2007-08-12 00:00:00.000  3797  1098         280
# ...            ...  ...                     ...   ...   ...         ...
# 1861290 1985-02-01  0.0 2017-12-25 19:30:50.746     9     0           0
# 1861291 1989-05-20  0.0 2014-12-24 00:00:00.000  1106     0           0
# 1861292 1988-01-04  0.0 2018-01-03 20:41:57.733     0     0           0
# 1861293 1988-01-04  0.0 2018-01-03 20:41:57.733     0     0           0
# 1861294 1988-01-04  0.0 2018-01-03 20:41:57.733     0     0           0
#
#          消费总金额  消费次数
# 301      38089    43
# 302      38089    43
# 303      38089    43
# 304      38089    43
# 305      38089    43
# ...        ...   ...
# 1861290      0     5
# 1861291      0     1
# 1861292      0     3
# 1861293      0     3
# 1861294      0     3
#
# [440058 rows x 20 columns]

# %% [markdown]
# ## 提取数据

# %%
Vip_data4.columns
# Out:
# Index(['会员卡号', '消费产生的时间', '商品编码', '销售数量', '商品售价', '消费金额', '商品名称', '此次消费的会员积分',
#        '收银机号', '单据号', '柜组编码', '柜组名称', '出生日期', '性别', '登记时间', '入会时长', '消费时长',
#        '最近一次消费距今时长', '消费总金额', '消费次数'],
#       dtype='object')

# %%
Vip_data4[{'入会时长','最近一次消费距今时长','消费总金额','消费次数'}]
# Out:
# C:\Users\31815\AppData\Local\Temp\ipykernel_19952\2352744778.py:1: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   Vip_data4[{'入会时长','最近一次消费距今时长','消费总金额','消费次数'}]
#          入会时长  消费总金额  消费次数  最近一次消费距今时长
# 301      3797  38089    43         280
# 302      3797  38089    43         280
# 303      3797  38089    43         280
# 304      3797  38089    43         280
# 305      3797  38089    43         280
# ...       ...    ...   ...         ...
# 1861290     9      0     5           0
# 1861291  1106      0     1           0
# 1861292     0      0     3           0
# 1861293     0      0     3           0
# 1861294     0      0     3           0
#
# [440058 rows x 4 columns]

# %% [markdown]
# ## 聚类

# %%
from sklearn.cluster import KMeans
model = KMeans(n_clusters=3)
model.fit(feature_N)
model.labels_
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Microsoftvscode\pythonTest\2homework3\test.ipynb 单元格 50 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/c%3A/Microsoftvscode/pythonTest/2homework3/test.ipynb#Y120sZmlsZQ%3D%3D?line=0'>1</a> from sklearn.cluster import KMeans
#       <a href='vscode-notebook-cell:/c%3A/Microsoftvscode/pythonTest/2homework3/test.ipynb#Y120sZmlsZQ%3D%3D?line=1'>2</a> model = KMeans(n_clusters=3)
# ----> <a href='vscode-notebook-cell:/c%3A/Microsoftvscode/pythonTest/2homework3/test.ipynb#Y120sZmlsZQ%3D%3D?line=2'>3</a> model.fit(feature_N)
#       <a href='vscode-notebook-cell:/c%3A/Microsoftvscode/pythonTest/2homework3/test.ipynb#Y120sZmlsZQ%3D%3D?line=3'>4</a> model.labels_
#
# NameError: name 'feature_N' is not defined

# %% [markdown]
# ## 标准化

# %%
from sklearn.
